# %%
import torch
import math
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torch.optim as optim
import matplotlib.pyplot as plt
import scipy.stats
from tqdm import tqdm

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
from nn_resampler import nn_resampler
from phase_est_smc import phase_est_smc

# %%
num_particles = 1000 # number of SMC particles (num of w points)
num_samples = 10000 # number of samples to draw from the particle distribution (to be binned)
num_bins = 100 # number of bins
n_iters = 1000 # number of different omega*
t0 = 0.1 # starting time
max_iters = 100 # maximum number of iterations before breaking
if_print = True

# %%
net = nn_resampler(100,100)
net.load_state_dict(torch.load("model/nn_resampler.model"))
net.eval();
# Out:
# nn_resampler(
#   (enc1): Linear(in_features=100, out_features=75, bias=True)
#   (enc2): Linear(in_features=75, out_features=50, bias=True)
#   (enc3): Linear(in_features=50, out_features=25, bias=True)
#   (enc4): Linear(in_features=25, out_features=10, bias=True)
#   (dec1): Linear(in_features=10, out_features=25, bias=True)
#   (dec2): Linear(in_features=25, out_features=50, bias=True)
#   (dec3): Linear(in_features=50, out_features=75, bias=True)
#   (dec4): Linear(in_features=75, out_features=100, bias=True)
#   (bn_enc1): BatchNorm1d(75, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_enc2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_enc3): BatchNorm1d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_enc4): BatchNorm1d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_dec1): BatchNorm1d(25, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_dec2): BatchNorm1d(50, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn_dec3): BatchNorm1d(75, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# )

# %% [markdown]
# ## NN Resampler

# %%
omega_star_list = []
nn_pred_list = []
nn_data = []

for i in range(n_iters): 
    
    omega_star = np.random.uniform(low=-1, high =1) * np.pi
    
    omega_star_list.append(omega_star)
    smc = phase_est_smc(omega_star, t0, max_iters)
    smc.init_particles(num_particles)
    resample_counts = 0
#     running_est = []
    
    while True:
        
        particle_pos, particle_wgts = smc.particles(threshold=num_particles/5, num_measurements=1)
        bins, edges = smc.get_bins(num_bins, num_samples)
        
        if smc.break_flag:
            break
            
        nn_pred = net(torch.tensor(bins).float().unsqueeze(0)) ## convert to float tensor, then make dim [1, num_bins]
        smc.nn_bins_to_particles(nn_pred.detach().numpy(), edges)
        
        resample_counts += 1

        
#         if len(running_est) > 5:
#             last_n = running_est[-5:]
#             # np.allclose(a,b) returns true if every element in a and b are equal to a tolerance
#             # np.full_like makes an array with shake of last_n with every element being last_n[0]
#             # if all elements of last_n are equal then they should all equal the first element
#             if np.allclose(last_n, np.full_like(last_n, last_n[0])):
#                 break
    if if_print:            
        print("True omega: {:f}, prediction by NN: {:f}, num of resample calls: {:d}".format(omega_star,
                                                                                             smc.curr_omega_est,
                                                                                             resample_counts))

    while len(smc.data) < max_iters:
        smc.data.append(smc.data[-1]) # append the last estimate
    
    if abs(smc.curr_omega_est - omega_star) > 1:
        print("Prediction: {:f}, actual value: {:f}. Threshold exceeded. Breaking out of loop for inspection.".
             format(smc.curr_omega_est, omega_star))
        break
                                                                                             
    nn_data.append(smc.data)
    nn_pred_list.append(smc.curr_omega_est)
# Out:
# True omega: -0.666746, prediction by NN: -0.665854, num of resample calls: 11
# True omega: -2.228710, prediction by NN: -2.228723, num of resample calls: 7
# True omega: -3.068929, prediction by NN: -3.068916, num of resample calls: 4
# True omega: -2.218239, prediction by NN: -2.213897, num of resample calls: 6
# True omega: -3.070551, prediction by NN: -3.070574, num of resample calls: 8
# True omega: -1.226795, prediction by NN: -1.226686, num of resample calls: 3
# True omega: -2.121394, prediction by NN: -2.121400, num of resample calls: 6
# True omega: 0.832978, prediction by NN: 0.832957, num of resample calls: 5
# True omega: 1.351022, prediction by NN: 1.351001, num of resample calls: 7
# True omega: -1.859677, prediction by NN: -1.859015, num of resample calls: 7
# True omega: 0.264724, prediction by NN: 0.264871, num of resample calls: 6
# True omega: -0.474126, prediction by NN: -0.474128, num of resample calls: 8
# True omega: 0.227464, prediction by NN: 0.227481, num of resample calls: 6
# True omega: 0.074052, prediction by NN: 0.074059, num of resample calls: 5
# True omega: -3.129360, prediction by NN: -3.125921, num of resample calls: 5
# True omega: -2.366623, prediction by NN: -2.366611, num of resample calls: 6
# True omega: 0.226370, prediction by NN: 0.226375, num of resample calls: 6
# True omega: -1.071343, prediction by NN: -1.071469, num of resample calls: 8
# True omega: 2.206881, prediction by NN: 2.205530, num of resample calls: 3
# True omega: -1.179784, prediction by NN: -1.165843, num of resample calls: 7
# True omega: -0.576407, prediction by NN: -0.581453, num of resample calls: 8
# True omega: 0.760648, prediction by NN: 0.760670, num of resample calls: 6
# True omega: 0.775923, prediction by NN: 0.775959, num of resample calls: 6
# True omega: 2.253545, prediction by NN: 2.253560, num of resample calls: 7
# True omega: 3.022515, prediction by NN: 3.098660, num of resample calls: 3
# True omega: 1.023281, prediction by NN: 1.037619, num of resample calls: 7
# True omega: 1.594435, prediction by NN: 1.668139, num of resample calls: 7
# True omega: -0.571311, prediction by NN: -0.571233, num of resample calls: 7
# True omega: -2.023961, prediction by NN: -2.023965, num of resample calls: 8
# True omega: 2.118417, prediction by NN: 2.118411, num of resample calls: 7
# True omega: 1.995070, prediction by NN: 1.995070, num of resample calls: 8
# True omega: -1.062912, prediction by NN: -1.066958, num of resample calls: 6
# True omega: -0.976811, prediction by NN: -0.976816, num of resample calls: 7
# True omega: 1.035909, prediction by NN: 1.035900, num of resample calls: 6
# True omega: -0.831126, prediction by NN: -0.831515, num of resample calls: 6
# True omega: -0.752435, prediction by NN: -0.752487, num of resample calls: 7
# True omega: 3.085789, prediction by NN: 3.085794, num of resample calls: 6
# True omega: -2.395124, prediction by NN: -2.395119, num of resample calls: 6
# True omega: -0.164747, prediction by NN: -0.164063, num of resample calls: 7
# True omega: 0.038976, prediction by NN: 0.038958, num of resample calls: 7
# True omega: -0.523298, prediction by NN: -0.524450, num of resample calls: 9
# True omega: 2.422157, prediction by NN: 2.422161, num of resample calls: 7
# True omega: -2.603454, prediction by NN: -2.603450, num of resample calls: 7
# True omega: -1.564382, prediction by NN: -1.564401, num of resample calls: 8
# True omega: 1.493958, prediction by NN: 1.503888, num of resample calls: 8
# True omega: 3.131324, prediction by NN: 2.772842, num of resample calls: 8
# True omega: -2.256197, prediction by NN: -2.256240, num of resample calls: 4
# True omega: -2.634810, prediction by NN: -2.652607, num of resample calls: 8
# True omega: -1.756775, prediction by NN: -1.756747, num of resample calls: 7
# True omega: -0.460528, prediction by NN: -0.460518, num of resample calls: 7
# True omega: 1.788621, prediction by NN: 1.789040, num of resample calls: 5
# True omega: 0.572032, prediction by NN: 0.572591, num of resample calls: 9
# True omega: 0.113966, prediction by NN: 0.114677, num of resample calls: 7
# True omega: 2.571741, prediction by NN: 2.571693, num of resample calls: 8
# True omega: 0.222187, prediction by NN: 0.220104, num of resample calls: 7
# True omega: 1.665057, prediction by NN: 1.665056, num of resample calls: 7
# True omega: -2.273819, prediction by NN: -2.273754, num of resample calls: 8
# True omega: 0.855164, prediction by NN: 0.859618, num of resample calls: 4
# True omega: -1.251381, prediction by NN: -1.251216, num of resample calls: 3
# True omega: 1.724574, prediction by NN: 1.724567, num of resample calls: 6
# True omega: 2.097710, prediction by NN: 2.097320, num of resample calls: 5
# True omega: -0.404767, prediction by NN: -0.404384, num of resample calls: 7
# True omega: 0.960798, prediction by NN: 0.960792, num of resample calls: 6
# True omega: 2.503547, prediction by NN: 2.506224, num of resample calls: 6
# True omega: 0.609273, prediction by NN: 0.609309, num of resample calls: 7
# True omega: 1.338146, prediction by NN: 1.350087, num of resample calls: 7
# True omega: 1.888279, prediction by NN: 1.889324, num of resample calls: 7
# True omega: 1.785757, prediction by NN: 1.785739, num of resample calls: 6
# True omega: 2.290254, prediction by NN: 2.290253, num of resample calls: 7
# True omega: -2.479206, prediction by NN: -2.473270, num of resample calls: 6
# True omega: -2.466301, prediction by NN: -2.466650, num of resample calls: 6
# True omega: -0.215868, prediction by NN: -0.215831, num of resample calls: 6
# True omega: 1.746156, prediction by NN: 1.746171, num of resample calls: 5
# True omega: -1.995574, prediction by NN: -1.999242, num of resample calls: 6
# True omega: 1.377041, prediction by NN: 1.377951, num of resample calls: 8
# True omega: 0.948281, prediction by NN: 0.948374, num of resample calls: 6
# True omega: -0.408831, prediction by NN: -0.409381, num of resample calls: 5
# True omega: 2.110029, prediction by NN: 2.110023, num of resample calls: 8
# True omega: -1.817793, prediction by NN: -1.817333, num of resample calls: 6
# True omega: -0.307422, prediction by NN: -0.295945, num of resample calls: 6
# True omega: 0.715076, prediction by NN: 0.715169, num of resample calls: 6
# True omega: -2.567696, prediction by NN: -2.567677, num of resample calls: 8
# True omega: -2.592969, prediction by NN: -2.592831, num of resample calls: 4
# True omega: 2.327812, prediction by NN: 2.327817, num of resample calls: 6
# True omega: 0.768440, prediction by NN: 0.768468, num of resample calls: 6
# True omega: -0.798110, prediction by NN: -0.784664, num of resample calls: 6
# True omega: -2.612828, prediction by NN: -2.612824, num of resample calls: 6
# True omega: -0.686963, prediction by NN: -0.699051, num of resample calls: 8
# True omega: 0.611624, prediction by NN: 0.611611, num of resample calls: 8
# True omega: 2.909044, prediction by NN: 2.908945, num of resample calls: 6
# True omega: 2.625575, prediction by NN: 2.625608, num of resample calls: 5
# True omega: 1.824361, prediction by NN: 1.824368, num of resample calls: 7
# True omega: -2.353410, prediction by NN: -2.369666, num of resample calls: 5
# True omega: 2.041320, prediction by NN: 2.041264, num of resample calls: 4
# True omega: 2.483148, prediction by NN: 2.483102, num of resample calls: 7
# True omega: -2.700819, prediction by NN: -2.701130, num of resample calls: 7
# True omega: -1.806801, prediction by NN: -1.806840, num of resample calls: 6
# True omega: -0.119755, prediction by NN: -0.130594, num of resample calls: 6
# True omega: 1.993505, prediction by NN: 1.993490, num of resample calls: 7
# True omega: -2.499117, prediction by NN: -2.499112, num of resample calls: 7
# True omega: 1.607788, prediction by NN: 1.607884, num of resample calls: 4
# True omega: -2.908532, prediction by NN: -2.912395, num of resample calls: 7
# True omega: 2.508089, prediction by NN: 2.506388, num of resample calls: 7
# True omega: 0.797809, prediction by NN: 0.797802, num of resample calls: 6
# True omega: -0.379085, prediction by NN: -0.379324, num of resample calls: 3
# True omega: -2.420619, prediction by NN: -2.422951, num of resample calls: 8
# True omega: 2.859033, prediction by NN: 2.859656, num of resample calls: 8
# True omega: 1.476776, prediction by NN: 1.476572, num of resample calls: 9
# True omega: 1.073055, prediction by NN: 1.073590, num of resample calls: 7
# True omega: -1.068128, prediction by NN: -1.068125, num of resample calls: 8
# True omega: -3.106551, prediction by NN: -3.119935, num of resample calls: 4
# True omega: 0.397890, prediction by NN: 0.397870, num of resample calls: 6
# True omega: -2.039588, prediction by NN: -2.039470, num of resample calls: 7
# True omega: -0.124301, prediction by NN: -0.123899, num of resample calls: 5
# True omega: 0.059680, prediction by NN: 0.059674, num of resample calls: 7
# True omega: 0.758464, prediction by NN: 0.758462, num of resample calls: 9
# True omega: 1.164842, prediction by NN: 1.165613, num of resample calls: 5
# True omega: 0.047490, prediction by NN: 0.047580, num of resample calls: 5
# True omega: 1.350347, prediction by NN: 1.350312, num of resample calls: 8
# True omega: -0.133142, prediction by NN: -0.133135, num of resample calls: 8
# True omega: -2.995672, prediction by NN: -2.977941, num of resample calls: 4
# True omega: 0.226681, prediction by NN: 0.227746, num of resample calls: 4
# True omega: 0.195216, prediction by NN: 0.193135, num of resample calls: 5
# True omega: 0.391689, prediction by NN: 0.391677, num of resample calls: 5
# True omega: -1.706479, prediction by NN: -1.709790, num of resample calls: 6
# True omega: 0.187958, prediction by NN: 0.187955, num of resample calls: 8
# True omega: -0.225363, prediction by NN: -0.482970, num of resample calls: 6
# True omega: -0.459166, prediction by NN: -0.459175, num of resample calls: 8
# True omega: -2.648046, prediction by NN: -2.648053, num of resample calls: 5
# True omega: -2.434532, prediction by NN: -2.434349, num of resample calls: 6
# True omega: 2.650737, prediction by NN: 2.650714, num of resample calls: 9
# True omega: 0.972687, prediction by NN: 0.964320, num of resample calls: 7
# True omega: 1.882345, prediction by NN: 1.882344, num of resample calls: 6
# True omega: -1.162574, prediction by NN: -1.153932, num of resample calls: 6
# True omega: -0.213244, prediction by NN: -0.230301, num of resample calls: 7
# True omega: -2.168289, prediction by NN: -2.069855, num of resample calls: 7
# True omega: 0.862589, prediction by NN: 0.856429, num of resample calls: 10
# True omega: -2.193578, prediction by NN: -2.193475, num of resample calls: 7
# True omega: -0.005407, prediction by NN: -0.005427, num of resample calls: 7
# True omega: 0.893647, prediction by NN: 0.886132, num of resample calls: 6
# True omega: -2.257890, prediction by NN: -2.341010, num of resample calls: 4
# True omega: 0.277689, prediction by NN: 0.276663, num of resample calls: 5
# True omega: -1.298860, prediction by NN: -1.298870, num of resample calls: 6
# True omega: -0.005667, prediction by NN: -0.007070, num of resample calls: 5
# True omega: 2.116370, prediction by NN: 2.116389, num of resample calls: 7
# True omega: 2.594339, prediction by NN: 2.591559, num of resample calls: 9
# True omega: -1.629052, prediction by NN: -1.629555, num of resample calls: 9
# True omega: 2.960393, prediction by NN: 2.959488, num of resample calls: 7
# True omega: 0.981831, prediction by NN: 0.984784, num of resample calls: 4
# True omega: 2.555838, prediction by NN: 2.064745, num of resample calls: 6
# True omega: 0.760517, prediction by NN: 0.713328, num of resample calls: 7
# True omega: -3.131664, prediction by NN: -3.073870, num of resample calls: 7
# True omega: -0.121845, prediction by NN: -0.121746, num of resample calls: 7
# True omega: -2.397053, prediction by NN: -2.396932, num of resample calls: 8
# True omega: 2.209455, prediction by NN: 2.209445, num of resample calls: 6
# True omega: 0.403857, prediction by NN: 0.403829, num of resample calls: 10
# True omega: 0.626337, prediction by NN: 0.626342, num of resample calls: 7
# True omega: 1.485660, prediction by NN: 1.485863, num of resample calls: 7
# True omega: -0.195815, prediction by NN: -0.195958, num of resample calls: 7
# True omega: -2.128742, prediction by NN: -2.129177, num of resample calls: 5
# True omega: 0.650781, prediction by NN: 0.652584, num of resample calls: 6
# True omega: -0.467369, prediction by NN: -0.466335, num of resample calls: 10
# True omega: -0.886522, prediction by NN: -0.886551, num of resample calls: 4
# True omega: 0.752426, prediction by NN: 0.735009, num of resample calls: 6
# True omega: -0.880073, prediction by NN: -0.880074, num of resample calls: 6
# True omega: 2.712816, prediction by NN: 2.717934, num of resample calls: 7
# True omega: 0.894253, prediction by NN: 0.892191, num of resample calls: 3
# True omega: 1.686981, prediction by NN: 1.686459, num of resample calls: 6
# True omega: -2.508613, prediction by NN: -2.508732, num of resample calls: 8
# True omega: 0.316891, prediction by NN: 0.316876, num of resample calls: 6
# True omega: -1.350228, prediction by NN: -1.349869, num of resample calls: 7
# True omega: 2.496696, prediction by NN: 2.496752, num of resample calls: 10
# True omega: 1.616127, prediction by NN: 1.616116, num of resample calls: 7
# True omega: 0.212499, prediction by NN: 0.186883, num of resample calls: 7
# True omega: -2.953573, prediction by NN: -2.977754, num of resample calls: 7
# True omega: 0.011790, prediction by NN: 0.011954, num of resample calls: 6
# True omega: -0.463207, prediction by NN: -0.467886, num of resample calls: 8
# True omega: -1.967710, prediction by NN: -1.967714, num of resample calls: 7
# True omega: 3.115397, prediction by NN: 3.097285, num of resample calls: 9
# True omega: -0.440424, prediction by NN: -0.440299, num of resample calls: 6
# True omega: -0.547391, prediction by NN: -0.547962, num of resample calls: 8
# True omega: -0.281756, prediction by NN: -0.281746, num of resample calls: 7
# True omega: -1.189666, prediction by NN: -1.189690, num of resample calls: 8
# True omega: -0.830838, prediction by NN: -0.830817, num of resample calls: 7
# True omega: 0.383738, prediction by NN: 0.383663, num of resample calls: 5
# True omega: -1.072907, prediction by NN: -1.065311, num of resample calls: 8
# True omega: -1.839417, prediction by NN: -1.839415, num of resample calls: 6
# True omega: 0.891901, prediction by NN: 0.891907, num of resample calls: 5
# True omega: 1.509849, prediction by NN: 1.509822, num of resample calls: 8
# True omega: -2.634889, prediction by NN: -2.634899, num of resample calls: 6
# True omega: -1.847100, prediction by NN: -1.847129, num of resample calls: 6
# True omega: -1.314401, prediction by NN: -1.314416, num of resample calls: 6
# True omega: -2.259367, prediction by NN: -2.259390, num of resample calls: 7
# True omega: -2.916290, prediction by NN: -2.916275, num of resample calls: 8
# True omega: -1.465874, prediction by NN: -1.460427, num of resample calls: 10
# True omega: 3.076966, prediction by NN: 3.076982, num of resample calls: 9
# True omega: -0.610518, prediction by NN: -0.609704, num of resample calls: 2
# True omega: -0.401271, prediction by NN: -0.401333, num of resample calls: 8
# True omega: -1.109036, prediction by NN: -1.111752, num of resample calls: 9
# True omega: 0.815953, prediction by NN: 0.815318, num of resample calls: 3
# True omega: -2.352614, prediction by NN: -2.205898, num of resample calls: 7
# True omega: 1.816529, prediction by NN: 1.823172, num of resample calls: 7
# True omega: -1.690510, prediction by NN: -1.690186, num of resample calls: 8
# True omega: -2.033999, prediction by NN: -2.034008, num of resample calls: 7
# True omega: 2.292063, prediction by NN: 2.288684, num of resample calls: 6
# True omega: 2.478056, prediction by NN: 2.478037, num of resample calls: 7
# True omega: -1.968306, prediction by NN: -1.968293, num of resample calls: 7
# True omega: -2.811036, prediction by NN: -2.813790, num of resample calls: 8
# True omega: -1.025554, prediction by NN: -1.025553, num of resample calls: 6
# True omega: 0.179809, prediction by NN: 0.179785, num of resample calls: 8
# True omega: 2.204589, prediction by NN: 2.203946, num of resample calls: 5
# True omega: -2.907747, prediction by NN: -2.907716, num of resample calls: 5
# True omega: 2.107371, prediction by NN: 2.099402, num of resample calls: 8
# True omega: -0.655032, prediction by NN: -0.652974, num of resample calls: 9
# True omega: -2.160192, prediction by NN: -2.159298, num of resample calls: 7
# True omega: -1.209208, prediction by NN: -1.123150, num of resample calls: 2
# True omega: 3.082867, prediction by NN: 2.972395, num of resample calls: 9
# True omega: -0.169478, prediction by NN: -0.176346, num of resample calls: 10
# True omega: -0.731940, prediction by NN: -0.731701, num of resample calls: 8
# True omega: -1.502239, prediction by NN: -1.502222, num of resample calls: 8
# True omega: -1.883796, prediction by NN: -1.869473, num of resample calls: 8
# True omega: -0.643345, prediction by NN: -0.646836, num of resample calls: 7
# True omega: 1.759983, prediction by NN: 1.734662, num of resample calls: 3
# True omega: 1.817172, prediction by NN: 1.817157, num of resample calls: 10
# True omega: 0.807781, prediction by NN: 0.801958, num of resample calls: 8
# True omega: 0.763024, prediction by NN: 0.764188, num of resample calls: 9
# True omega: -3.138969, prediction by NN: -2.684702, num of resample calls: 8
# True omega: 1.097696, prediction by NN: 1.081928, num of resample calls: 5
# True omega: 1.259291, prediction by NN: 1.259291, num of resample calls: 7
# True omega: 2.892798, prediction by NN: 2.898423, num of resample calls: 6
# True omega: -1.031340, prediction by NN: -1.031347, num of resample calls: 7
# True omega: 0.171365, prediction by NN: 0.171400, num of resample calls: 7
# True omega: 0.030282, prediction by NN: 0.037594, num of resample calls: 7
# True omega: -1.137241, prediction by NN: -1.010466, num of resample calls: 11
# True omega: -0.388339, prediction by NN: -0.388322, num of resample calls: 5
# True omega: -2.129006, prediction by NN: -2.129005, num of resample calls: 6
# True omega: 0.895254, prediction by NN: 0.796620, num of resample calls: 7
# True omega: 3.001447, prediction by NN: 2.989974, num of resample calls: 6
# True omega: 1.993188, prediction by NN: 1.989630, num of resample calls: 7
# True omega: 2.576348, prediction by NN: 2.587640, num of resample calls: 4
# True omega: -1.697415, prediction by NN: -1.697450, num of resample calls: 5
# True omega: 2.409636, prediction by NN: 2.409283, num of resample calls: 6
# True omega: 2.767792, prediction by NN: 2.767908, num of resample calls: 7
# True omega: -2.982157, prediction by NN: -2.986931, num of resample calls: 6
# True omega: -1.379659, prediction by NN: -1.390579, num of resample calls: 5
# True omega: 1.280549, prediction by NN: 1.279115, num of resample calls: 4
# True omega: 0.908567, prediction by NN: 0.908551, num of resample calls: 8
# True omega: 0.106688, prediction by NN: 0.101770, num of resample calls: 5
# True omega: -2.723650, prediction by NN: -2.723668, num of resample calls: 6
# True omega: -0.546103, prediction by NN: -0.546801, num of resample calls: 6
# True omega: 1.172412, prediction by NN: 1.172417, num of resample calls: 5
# True omega: -1.452097, prediction by NN: -1.459574, num of resample calls: 5
# True omega: -2.368128, prediction by NN: -2.388976, num of resample calls: 3
# True omega: 0.968374, prediction by NN: 0.968374, num of resample calls: 6
# True omega: -1.060043, prediction by NN: -1.182513, num of resample calls: 6
# True omega: 0.401194, prediction by NN: 0.401563, num of resample calls: 9
# True omega: -2.523397, prediction by NN: -2.523356, num of resample calls: 5
# True omega: -1.020061, prediction by NN: -1.020069, num of resample calls: 6
# True omega: -1.693111, prediction by NN: -1.827763, num of resample calls: 4
# True omega: 0.728987, prediction by NN: 0.716076, num of resample calls: 9
# True omega: 1.934490, prediction by NN: 1.934651, num of resample calls: 6
# True omega: 0.404934, prediction by NN: 0.404513, num of resample calls: 5
# True omega: -1.270202, prediction by NN: -1.270197, num of resample calls: 7
# True omega: -0.745047, prediction by NN: -0.689534, num of resample calls: 4
# True omega: -0.303259, prediction by NN: -0.303274, num of resample calls: 6
# True omega: -2.088390, prediction by NN: -2.088389, num of resample calls: 7
# True omega: 3.132754, prediction by NN: 3.109973, num of resample calls: 11
# True omega: -0.963546, prediction by NN: -0.960656, num of resample calls: 5
# True omega: -2.202945, prediction by NN: -2.202926, num of resample calls: 8
# True omega: 1.765802, prediction by NN: 1.765789, num of resample calls: 8
# True omega: 2.307209, prediction by NN: 2.324828, num of resample calls: 3
# True omega: -2.491446, prediction by NN: -2.487388, num of resample calls: 9
# True omega: -2.692275, prediction by NN: -2.709584, num of resample calls: 6
# True omega: 0.783080, prediction by NN: 0.778383, num of resample calls: 6
# True omega: 1.646964, prediction by NN: 1.646974, num of resample calls: 8
# True omega: -0.486829, prediction by NN: -0.486713, num of resample calls: 6
# True omega: 1.350944, prediction by NN: 1.350666, num of resample calls: 6
# True omega: -2.394251, prediction by NN: -2.394201, num of resample calls: 7
# True omega: 1.045049, prediction by NN: 0.892835, num of resample calls: 7
# True omega: -1.092547, prediction by NN: -1.092551, num of resample calls: 11
# True omega: -1.489191, prediction by NN: -1.525699, num of resample calls: 6
# True omega: -1.163039, prediction by NN: -1.163044, num of resample calls: 8
# True omega: 1.284449, prediction by NN: 1.313634, num of resample calls: 5
# True omega: -3.061940, prediction by NN: -3.061972, num of resample calls: 7
# True omega: 0.576226, prediction by NN: 0.576236, num of resample calls: 5
# True omega: -2.943534, prediction by NN: -2.927711, num of resample calls: 2
# True omega: 2.862549, prediction by NN: 2.862787, num of resample calls: 8
# True omega: 1.520191, prediction by NN: 1.520183, num of resample calls: 6
# True omega: -0.424392, prediction by NN: -0.424395, num of resample calls: 7
# True omega: 1.156609, prediction by NN: 1.157781, num of resample calls: 6
# True omega: 1.385941, prediction by NN: 1.385939, num of resample calls: 7
# True omega: -2.108437, prediction by NN: -2.108435, num of resample calls: 6
# True omega: -2.444638, prediction by NN: -2.438076, num of resample calls: 6
# True omega: -0.137855, prediction by NN: -0.135778, num of resample calls: 7
# True omega: -0.472545, prediction by NN: -0.474744, num of resample calls: 4
# True omega: 2.995885, prediction by NN: 2.995895, num of resample calls: 6
# True omega: 1.680805, prediction by NN: 1.702404, num of resample calls: 6
# True omega: -0.417081, prediction by NN: -0.416737, num of resample calls: 6
# True omega: -0.750572, prediction by NN: -0.745498, num of resample calls: 7
# True omega: 2.428283, prediction by NN: 2.428594, num of resample calls: 5
# True omega: -1.896908, prediction by NN: -1.896908, num of resample calls: 7
# True omega: -2.282851, prediction by NN: -2.282753, num of resample calls: 4
# True omega: -1.931132, prediction by NN: -1.931894, num of resample calls: 6
# True omega: -0.096687, prediction by NN: -0.118829, num of resample calls: 3
# True omega: 2.651798, prediction by NN: 2.651773, num of resample calls: 8
# True omega: 2.245339, prediction by NN: 2.244686, num of resample calls: 5
# True omega: 2.413973, prediction by NN: 2.413715, num of resample calls: 5
# True omega: -2.131771, prediction by NN: -2.131817, num of resample calls: 7
# True omega: -2.267245, prediction by NN: -2.250342, num of resample calls: 6
# True omega: 2.141472, prediction by NN: 2.085801, num of resample calls: 12
# True omega: 3.113607, prediction by NN: 3.108920, num of resample calls: 2
# True omega: -2.769132, prediction by NN: -2.769133, num of resample calls: 8
# True omega: -1.869210, prediction by NN: -1.869196, num of resample calls: 6
# True omega: 1.210976, prediction by NN: 1.210940, num of resample calls: 4
# True omega: -0.340301, prediction by NN: -0.340345, num of resample calls: 5
# True omega: -2.351849, prediction by NN: -2.034780, num of resample calls: 5
# True omega: 1.541374, prediction by NN: 1.541699, num of resample calls: 7
# True omega: -1.743507, prediction by NN: -1.743503, num of resample calls: 7
# True omega: -2.667662, prediction by NN: -2.667665, num of resample calls: 8
# True omega: 0.991354, prediction by NN: 0.991674, num of resample calls: 3
# True omega: 1.297237, prediction by NN: 1.297251, num of resample calls: 5
# True omega: -2.910852, prediction by NN: -2.911550, num of resample calls: 7
# True omega: 1.093135, prediction by NN: 1.097002, num of resample calls: 6
# True omega: 2.466707, prediction by NN: 2.482935, num of resample calls: 2
# True omega: 2.388268, prediction by NN: 2.390715, num of resample calls: 5
# True omega: 0.442790, prediction by NN: 0.438739, num of resample calls: 6
# True omega: 3.080914, prediction by NN: 3.080857, num of resample calls: 7
# True omega: 1.837742, prediction by NN: 1.837741, num of resample calls: 6
# True omega: 1.228286, prediction by NN: 1.227834, num of resample calls: 5
# True omega: -3.019335, prediction by NN: -3.019311, num of resample calls: 7
# True omega: -1.219220, prediction by NN: -1.219122, num of resample calls: 3
# True omega: 2.410970, prediction by NN: 2.752131, num of resample calls: 7
# True omega: -1.853120, prediction by NN: -1.853091, num of resample calls: 9
# True omega: 0.076715, prediction by NN: 0.073858, num of resample calls: 9
# True omega: 3.073716, prediction by NN: 3.051559, num of resample calls: 6
# True omega: 1.463563, prediction by NN: 1.463551, num of resample calls: 7
# True omega: 0.508488, prediction by NN: 0.508477, num of resample calls: 8
# True omega: 0.009655, prediction by NN: 0.085846, num of resample calls: 10
# True omega: -0.934567, prediction by NN: -0.935952, num of resample calls: 6
# True omega: 2.713120, prediction by NN: 2.713223, num of resample calls: 9
# True omega: 0.730012, prediction by NN: 0.642864, num of resample calls: 4
# True omega: 2.252118, prediction by NN: 2.259176, num of resample calls: 4
# True omega: -0.571144, prediction by NN: -0.571117, num of resample calls: 7
# True omega: 2.628379, prediction by NN: 2.631061, num of resample calls: 3
# True omega: -2.472785, prediction by NN: -2.778759, num of resample calls: 9
# True omega: -2.554011, prediction by NN: -2.553947, num of resample calls: 7
# True omega: -0.109811, prediction by NN: -0.110732, num of resample calls: 7
# True omega: -2.421922, prediction by NN: -2.420353, num of resample calls: 4
# True omega: 1.708800, prediction by NN: 1.682316, num of resample calls: 6
# True omega: -0.681918, prediction by NN: -0.681934, num of resample calls: 9
# True omega: 1.140649, prediction by NN: 1.140675, num of resample calls: 6
# True omega: -1.155663, prediction by NN: -1.559633, num of resample calls: 8
# True omega: 0.693046, prediction by NN: 0.689763, num of resample calls: 8
# True omega: 0.917801, prediction by NN: 0.941273, num of resample calls: 6
# True omega: 1.866528, prediction by NN: 1.717778, num of resample calls: 6
# True omega: -1.487841, prediction by NN: -1.487829, num of resample calls: 5
# True omega: -2.551430, prediction by NN: -2.551451, num of resample calls: 5
# True omega: -0.449727, prediction by NN: -0.449808, num of resample calls: 6
# True omega: -0.983562, prediction by NN: -0.979269, num of resample calls: 5
# True omega: 2.075372, prediction by NN: 2.075364, num of resample calls: 7
# True omega: 1.191096, prediction by NN: 1.191104, num of resample calls: 6
# True omega: 1.448081, prediction by NN: 1.448037, num of resample calls: 4
# True omega: -1.927711, prediction by NN: -1.927537, num of resample calls: 6
# True omega: 2.303671, prediction by NN: 2.312353, num of resample calls: 4
# True omega: -1.856836, prediction by NN: -1.856560, num of resample calls: 7
# True omega: 2.134689, prediction by NN: 2.136242, num of resample calls: 8
# True omega: -0.822070, prediction by NN: -0.814926, num of resample calls: 9
# True omega: -2.077076, prediction by NN: -2.080375, num of resample calls: 6
# True omega: -0.260874, prediction by NN: -0.266151, num of resample calls: 8
# True omega: 2.136662, prediction by NN: 2.135021, num of resample calls: 4
# True omega: 2.240303, prediction by NN: 2.240291, num of resample calls: 8
# True omega: -3.050959, prediction by NN: -3.047004, num of resample calls: 9
# True omega: 1.841401, prediction by NN: 1.841439, num of resample calls: 9
# True omega: 2.060554, prediction by NN: 2.060538, num of resample calls: 6
# True omega: -2.262594, prediction by NN: -2.262585, num of resample calls: 6
# True omega: -2.518718, prediction by NN: -2.518716, num of resample calls: 7
# True omega: -1.397310, prediction by NN: -1.403127, num of resample calls: 4
# True omega: 0.681934, prediction by NN: 0.610856, num of resample calls: 5
# True omega: -1.727072, prediction by NN: -1.727104, num of resample calls: 4
# True omega: -1.431906, prediction by NN: -1.431927, num of resample calls: 7
# True omega: -1.740714, prediction by NN: -1.740725, num of resample calls: 7
# True omega: -0.204487, prediction by NN: -0.205572, num of resample calls: 3
# True omega: -2.335822, prediction by NN: -2.331960, num of resample calls: 8
# True omega: 0.464731, prediction by NN: 0.464537, num of resample calls: 5
# True omega: -0.947021, prediction by NN: -0.947004, num of resample calls: 6
# True omega: 2.576320, prediction by NN: 2.576289, num of resample calls: 8
# True omega: 1.040577, prediction by NN: 1.040350, num of resample calls: 7
# True omega: 0.092716, prediction by NN: 0.094105, num of resample calls: 6
# True omega: 0.476745, prediction by NN: 0.476735, num of resample calls: 6
# True omega: 0.723802, prediction by NN: 0.714688, num of resample calls: 6
# True omega: -3.124014, prediction by NN: -3.124951, num of resample calls: 2
# True omega: 0.197224, prediction by NN: 0.197219, num of resample calls: 7
# True omega: 0.985784, prediction by NN: 0.985823, num of resample calls: 6
# True omega: -0.575094, prediction by NN: -0.575106, num of resample calls: 7
# True omega: -0.431571, prediction by NN: -0.911391, num of resample calls: 9
# True omega: -2.673678, prediction by NN: -2.672784, num of resample calls: 7
# True omega: 3.118440, prediction by NN: 3.118490, num of resample calls: 6
# True omega: 0.452225, prediction by NN: 0.467205, num of resample calls: 6
# True omega: -0.337291, prediction by NN: -0.338479, num of resample calls: 2
# True omega: 0.114302, prediction by NN: 0.114408, num of resample calls: 6
# True omega: -0.958171, prediction by NN: -0.958161, num of resample calls: 7
# True omega: 0.709291, prediction by NN: 0.709261, num of resample calls: 6
# True omega: 1.215267, prediction by NN: 1.215251, num of resample calls: 6
# True omega: 0.641245, prediction by NN: 0.641211, num of resample calls: 7
# True omega: 0.122363, prediction by NN: 0.122363, num of resample calls: 6
# True omega: 2.781877, prediction by NN: 2.798312, num of resample calls: 9
# True omega: -2.581034, prediction by NN: -2.581128, num of resample calls: 8
# True omega: -1.004751, prediction by NN: -1.002935, num of resample calls: 7
# True omega: 0.038769, prediction by NN: 0.037826, num of resample calls: 6
# True omega: 1.535844, prediction by NN: 1.535824, num of resample calls: 5
# True omega: 0.144168, prediction by NN: 0.144173, num of resample calls: 7
# True omega: -0.194404, prediction by NN: -0.192893, num of resample calls: 10
# True omega: 1.504730, prediction by NN: 0.965261, num of resample calls: 6
# True omega: -0.620205, prediction by NN: -0.622845, num of resample calls: 9
# True omega: 0.106564, prediction by NN: 0.106751, num of resample calls: 6
# True omega: 2.616863, prediction by NN: 2.616856, num of resample calls: 6
# True omega: -2.666112, prediction by NN: -2.667579, num of resample calls: 4
# True omega: -2.328002, prediction by NN: -2.327814, num of resample calls: 5
# True omega: 0.166753, prediction by NN: 0.174510, num of resample calls: 6
# True omega: -0.994369, prediction by NN: -0.994327, num of resample calls: 6
# True omega: -1.402355, prediction by NN: -1.409121, num of resample calls: 6
# True omega: -2.913907, prediction by NN: -2.913912, num of resample calls: 8
# True omega: -2.283071, prediction by NN: -2.283367, num of resample calls: 6
# True omega: -1.789315, prediction by NN: -1.789316, num of resample calls: 7
# True omega: 2.148567, prediction by NN: 2.148556, num of resample calls: 7
# True omega: -1.802176, prediction by NN: -1.802219, num of resample calls: 4
# True omega: 1.087792, prediction by NN: 1.087537, num of resample calls: 5
# True omega: -1.946367, prediction by NN: -1.946394, num of resample calls: 9
# True omega: 1.427160, prediction by NN: 1.430678, num of resample calls: 9
# True omega: 2.027553, prediction by NN: 2.027686, num of resample calls: 5
# True omega: -2.736227, prediction by NN: -2.735654, num of resample calls: 7
# True omega: -1.258813, prediction by NN: -1.351993, num of resample calls: 7
# True omega: 0.572488, prediction by NN: 0.575413, num of resample calls: 5
# True omega: 1.974238, prediction by NN: 1.951566, num of resample calls: 4
# True omega: 1.758731, prediction by NN: 1.758710, num of resample calls: 6
# True omega: 0.372865, prediction by NN: 0.356849, num of resample calls: 8
# True omega: -2.416327, prediction by NN: -2.416326, num of resample calls: 7
# True omega: 3.122014, prediction by NN: 2.928277, num of resample calls: 7
# True omega: 2.393911, prediction by NN: 2.393930, num of resample calls: 6
# True omega: -0.394638, prediction by NN: -0.396756, num of resample calls: 7
# True omega: -0.534427, prediction by NN: -0.557633, num of resample calls: 7
# True omega: -0.566589, prediction by NN: -0.566817, num of resample calls: 5
# True omega: 0.552600, prediction by NN: 0.552585, num of resample calls: 7
# True omega: 1.697184, prediction by NN: 1.697168, num of resample calls: 7
# True omega: -1.360676, prediction by NN: -1.361079, num of resample calls: 3
# True omega: 0.330696, prediction by NN: 0.326657, num of resample calls: 6
# True omega: 1.527049, prediction by NN: 1.527068, num of resample calls: 7
# True omega: -2.461053, prediction by NN: -2.461073, num of resample calls: 6
# True omega: 2.191204, prediction by NN: 2.349700, num of resample calls: 8
# True omega: -1.193272, prediction by NN: -1.193931, num of resample calls: 5
# True omega: -1.198005, prediction by NN: -1.198331, num of resample calls: 7
# True omega: 2.725020, prediction by NN: 2.727658, num of resample calls: 7
# True omega: 2.561236, prediction by NN: 2.561245, num of resample calls: 7
# True omega: -1.814554, prediction by NN: -1.814558, num of resample calls: 6
# True omega: -0.942952, prediction by NN: -0.978993, num of resample calls: 5
# True omega: 2.965677, prediction by NN: 2.965680, num of resample calls: 8
# True omega: 0.411529, prediction by NN: 0.411740, num of resample calls: 7
# True omega: -1.511250, prediction by NN: -1.511223, num of resample calls: 10
# True omega: 2.183209, prediction by NN: 2.182788, num of resample calls: 8
# True omega: 2.282286, prediction by NN: 2.282266, num of resample calls: 6
# True omega: 0.408362, prediction by NN: 0.407132, num of resample calls: 6
# True omega: -0.947918, prediction by NN: -0.947936, num of resample calls: 6
# True omega: 0.652240, prediction by NN: 0.056710, num of resample calls: 5
# True omega: -2.268912, prediction by NN: -2.268879, num of resample calls: 7
# True omega: -0.857399, prediction by NN: -0.857980, num of resample calls: 9
# True omega: 0.030344, prediction by NN: 0.030364, num of resample calls: 5
# True omega: 2.505909, prediction by NN: 2.506226, num of resample calls: 6
# True omega: -2.082902, prediction by NN: -2.083611, num of resample calls: 7
# True omega: 0.951250, prediction by NN: 0.951705, num of resample calls: 4
# True omega: 0.983114, prediction by NN: 0.950733, num of resample calls: 7
# True omega: -1.065829, prediction by NN: -1.065827, num of resample calls: 6
# True omega: 0.499135, prediction by NN: 0.502293, num of resample calls: 5
# True omega: 2.516542, prediction by NN: 2.516553, num of resample calls: 5
# True omega: -2.980304, prediction by NN: -2.982798, num of resample calls: 5
# True omega: 1.601160, prediction by NN: 1.601253, num of resample calls: 7
# True omega: 0.879692, prediction by NN: 0.879699, num of resample calls: 8
# True omega: 1.606018, prediction by NN: 1.662336, num of resample calls: 8
# True omega: 0.508529, prediction by NN: 0.511940, num of resample calls: 5
# True omega: -0.406674, prediction by NN: -0.406648, num of resample calls: 6
# True omega: -1.568080, prediction by NN: -1.571058, num of resample calls: 6
# True omega: -0.291641, prediction by NN: -0.295349, num of resample calls: 4
# True omega: 0.154819, prediction by NN: 0.081869, num of resample calls: 5
# True omega: 2.116986, prediction by NN: 2.116859, num of resample calls: 5
# True omega: 0.688367, prediction by NN: 0.688308, num of resample calls: 10
# True omega: 1.450432, prediction by NN: 1.449171, num of resample calls: 6
# True omega: -0.100722, prediction by NN: -0.101590, num of resample calls: 8
# True omega: 2.475937, prediction by NN: 2.475921, num of resample calls: 8
# True omega: -0.644629, prediction by NN: -0.650208, num of resample calls: 8
# True omega: -1.656441, prediction by NN: -1.655812, num of resample calls: 6
# True omega: 2.562687, prediction by NN: 2.562692, num of resample calls: 8
# True omega: 1.517400, prediction by NN: 1.517268, num of resample calls: 8
# True omega: 2.948596, prediction by NN: 2.970837, num of resample calls: 8
# True omega: 2.888415, prediction by NN: 2.888448, num of resample calls: 6
# True omega: -2.029015, prediction by NN: -2.029018, num of resample calls: 9
# True omega: 0.395593, prediction by NN: 0.395579, num of resample calls: 6
# True omega: -2.206392, prediction by NN: -2.214760, num of resample calls: 6
# True omega: -1.816438, prediction by NN: -1.702057, num of resample calls: 9
# True omega: 2.615663, prediction by NN: 2.615676, num of resample calls: 4
# True omega: -2.821931, prediction by NN: -2.822759, num of resample calls: 9
# True omega: -2.892329, prediction by NN: -2.892308, num of resample calls: 6
# True omega: 3.036502, prediction by NN: 2.922060, num of resample calls: 5
# True omega: 2.421076, prediction by NN: 2.420377, num of resample calls: 5
# True omega: -3.126031, prediction by NN: -3.126040, num of resample calls: 8
# True omega: -1.214765, prediction by NN: -1.214498, num of resample calls: 7
# True omega: 1.160641, prediction by NN: 1.160377, num of resample calls: 3
# True omega: 0.991136, prediction by NN: 0.991140, num of resample calls: 7
# True omega: 0.411664, prediction by NN: 0.410935, num of resample calls: 7
# True omega: -1.226838, prediction by NN: -1.229847, num of resample calls: 6
# True omega: 1.181609, prediction by NN: 1.175095, num of resample calls: 5
# True omega: -1.359962, prediction by NN: -1.366553, num of resample calls: 7
# True omega: -1.296103, prediction by NN: -1.296120, num of resample calls: 6
# True omega: -2.207072, prediction by NN: -2.207067, num of resample calls: 6
# True omega: -2.874447, prediction by NN: -2.877627, num of resample calls: 6
# True omega: -0.007409, prediction by NN: -0.014235, num of resample calls: 8
# True omega: 2.703984, prediction by NN: 2.703994, num of resample calls: 7
# True omega: -1.561584, prediction by NN: -1.557237, num of resample calls: 8
# True omega: -3.131911, prediction by NN: -3.100608, num of resample calls: 5
# True omega: -0.649072, prediction by NN: -0.650115, num of resample calls: 8
# True omega: -1.549683, prediction by NN: -1.549627, num of resample calls: 5
# True omega: 2.202926, prediction by NN: 2.192792, num of resample calls: 8
# True omega: 2.570758, prediction by NN: 2.506777, num of resample calls: 8
# True omega: 0.765152, prediction by NN: 0.781974, num of resample calls: 6
# True omega: -0.562923, prediction by NN: -0.562876, num of resample calls: 7
# True omega: 1.888825, prediction by NN: 1.879934, num of resample calls: 3
# True omega: -0.113189, prediction by NN: -0.114937, num of resample calls: 6
# True omega: -1.121213, prediction by NN: -1.105847, num of resample calls: 6
# True omega: -1.739190, prediction by NN: -1.739175, num of resample calls: 6
# True omega: -0.675734, prediction by NN: -0.536935, num of resample calls: 4
# True omega: 1.025653, prediction by NN: 1.026558, num of resample calls: 6
# True omega: -0.376462, prediction by NN: -0.376474, num of resample calls: 6
# True omega: -2.646626, prediction by NN: -2.782435, num of resample calls: 7
# True omega: -2.803770, prediction by NN: -2.803739, num of resample calls: 7
# True omega: 0.209229, prediction by NN: 0.209255, num of resample calls: 8
# True omega: 0.644263, prediction by NN: 0.645430, num of resample calls: 5
# True omega: 0.352201, prediction by NN: 0.340963, num of resample calls: 8
# True omega: 1.594269, prediction by NN: 1.593809, num of resample calls: 8
# True omega: 0.035511, prediction by NN: 0.035504, num of resample calls: 7
# True omega: -0.956914, prediction by NN: -0.956869, num of resample calls: 8
# True omega: -0.038592, prediction by NN: -0.040670, num of resample calls: 5
# True omega: -3.012815, prediction by NN: -3.012841, num of resample calls: 4
# True omega: 2.547604, prediction by NN: 2.548498, num of resample calls: 2
# True omega: -1.318135, prediction by NN: -1.318160, num of resample calls: 10
# True omega: -2.269038, prediction by NN: -2.272900, num of resample calls: 6
# True omega: -1.562135, prediction by NN: -1.562117, num of resample calls: 10
# True omega: 1.006570, prediction by NN: 1.008129, num of resample calls: 8
# True omega: -2.029556, prediction by NN: -2.029544, num of resample calls: 8
# True omega: -2.946962, prediction by NN: -2.971219, num of resample calls: 4
# True omega: -2.586435, prediction by NN: -2.586457, num of resample calls: 6
# True omega: -1.430986, prediction by NN: -1.430953, num of resample calls: 7
# True omega: -0.358114, prediction by NN: -0.358115, num of resample calls: 6
# True omega: -2.307606, prediction by NN: -2.307463, num of resample calls: 5
# True omega: 0.431728, prediction by NN: 0.431724, num of resample calls: 7
# True omega: -1.382003, prediction by NN: -1.378666, num of resample calls: 7
# True omega: -2.575941, prediction by NN: -2.575457, num of resample calls: 4
# True omega: -0.082018, prediction by NN: -0.082060, num of resample calls: 6
# True omega: 2.700585, prediction by NN: 2.701009, num of resample calls: 9
# True omega: 0.534567, prediction by NN: 0.526180, num of resample calls: 7
# True omega: 2.963590, prediction by NN: 2.963703, num of resample calls: 7
# True omega: -1.179088, prediction by NN: -1.179069, num of resample calls: 6
# True omega: 1.304807, prediction by NN: 1.304817, num of resample calls: 6
# True omega: -1.102597, prediction by NN: -1.102598, num of resample calls: 7
# True omega: 2.125434, prediction by NN: 2.125344, num of resample calls: 6
# True omega: 2.673629, prediction by NN: 2.673593, num of resample calls: 6
# True omega: 2.485145, prediction by NN: 2.476292, num of resample calls: 7
# True omega: -1.151732, prediction by NN: -1.144738, num of resample calls: 6
# True omega: 2.978734, prediction by NN: 2.980245, num of resample calls: 3
# True omega: 2.217679, prediction by NN: 2.217691, num of resample calls: 8
# True omega: 0.977311, prediction by NN: 0.977282, num of resample calls: 8
# True omega: -2.949617, prediction by NN: -2.993632, num of resample calls: 4
# True omega: 0.179398, prediction by NN: 0.179391, num of resample calls: 8
# True omega: 1.352524, prediction by NN: 1.350453, num of resample calls: 6
# True omega: -0.714400, prediction by NN: -0.714399, num of resample calls: 10
# True omega: -2.645926, prediction by NN: -2.645939, num of resample calls: 7
# True omega: 1.841055, prediction by NN: 1.841058, num of resample calls: 6
# True omega: 2.695750, prediction by NN: 2.696210, num of resample calls: 9
# True omega: -2.169362, prediction by NN: -2.093965, num of resample calls: 4
# True omega: -2.630694, prediction by NN: -1.583505, num of resample calls: 9
# Prediction: -1.583505, actual value: -2.630694. Threshold exceeded. Breaking out of loop for inspection.

# %%
for i in range(len(smc.memory.pos_wgt_bef_res)-1):
    pos_bef_res = smc.memory.pos_wgt_bef_res[i][0]
    wgt_bef_res = smc.memory.pos_wgt_bef_res[i][1]
    bins_bef_res = smc.memory.bins_edges_bef_res[i][0]
    edges_bef_res = smc.memory.bins_edges_bef_res[i][1]
    bins_aft_res = smc.memory.bins_edges_aft_res[i][0]
    edges_aft_res = edges_bef_res
    pos_aft_res = smc.memory.pos_wgt_aft_res[i][0]
    wgt_aft_res = smc.memory.pos_wgt_aft_res[i][1]
    edge_width = edges_bef_res[1] - edges_bef_res[0]
    
    fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(18,6))
    
    ax1.bar(pos_bef_res, wgt_bef_res, label='particle pos')
    ax1.bar(edges_bef_res, bins_bef_res, align='edge', width = edge_width, alpha=0.5,color='green', label='bins before res')
    ax1.set_xlim([-np.pi, np.pi])
    ax1.axvline(omega_star,color='black')
    ax1.set_title("Before resampling")
    ax1.legend()
    
    ax2.bar(edges_bef_res, bins_bef_res, align='edge', width = edge_width, label='bins before res', color='green',alpha=0.5)
    ax2.bar(edges_aft_res, bins_aft_res, align='edge', width = edge_width, label='after res')
    ax2.set_xlim([-np.pi, np.pi])
    #ax2.axvline(omega_star, color='black')
    ax2.set_title("After resampling")
    ax2.legend()
    
    ax3.bar(pos_aft_res, wgt_aft_res)
    ax3.axvline(omega_star, color='black')
    ax3.set_xlim([-np.pi, np.pi])
    ax3.set_title("Positions and wgts after resampling")
    
    plt.show()

# %%
nn_mse = np.mean( np.array(omega_star_list) - np.array(nn_pred_list) ) ** 2
print(nn_mse)

# %%
nn_data_squared = (np.array(nn_data) - np.array(omega_star_list).reshape(-1,1)) ** 2 
nn_data_mean = np.mean(nn_data_squared, axis=0)
nn_data_median = np.median(nn_data_squared, axis =0)

num_data_points = nn_data_squared.shape[1]

plt.plot(np.arange(1,num_data_points+1, dtype=int), nn_data_mean, label='Mean')
plt.plot(np.arange(1,num_data_points+1, dtype=int), nn_data_median, label='Median')
plt.legend()
plt.title("NN")
plt.yscale('log')
plt.xlabel("Iters")
plt.ylabel("$(\omega - \omega*)^2$")
plt.show()

# %% [markdown]
# ## Liu-West resampler

# %%
omega_star_list = []
lw_pred_list = []
lw_data = []

for i in range(n_iters): 
    omega_star = np.random.uniform(low=-1, high=1) * np.pi
    
    omega_star_list.append(omega_star)
    smc = phase_est_smc(omega_star, t0, max_iters)
    smc.init_particles(num_particles)
#     running_est = []
    
    counts = 0
    
    while True:

        particle_pos, particle_wgts = smc.particles(threshold=num_particles/10, num_measurements=1)
        smc.liu_west_resample()
        
#         if counts == 0:
#             fig, (ax1, ax2) = plt.subplots(1,2, figsize=(20,10))
#             ax1.bar(particle_pos, particle_wgts)
#             ax2.bar(smc.particle_pos, smc.particle_wgts)
#             plt.show()
        
        counts+= 1 
        
        curr_omega_est = smc.particle_pos[np.argmax(smc.particle_wgts)]
        if smc.break_flag == True:
            break
            
#         running_est.append(curr_omega_est)
        
#         if len(running_est) > 5:
#             last_5 = running_est[-5:]
#             # np.allclose(a,b) returns true if every element in a and b are equal to a tolerance
#             # np.full_like makes an array with shape of last_10 with every element being last_10[0]
#             # if all elements of last_10 are equal then they should all equal the first element
#             if np.allclose(last_5, np.full_like(last_5, last_5[0])):
#                 break
                
      
    print("True omega: {:f}, prediction by LW: {:f}, num of resample calls: {:d}".format(omega_star,curr_omega_est, counts))
    lw_pred_list.append(curr_omega_est)

    while len(smc.data) < max_iters:
        smc.data.append(smc.data[-1]) # append the last estimate 
    
    lw_data.append(smc.data)
# Out:
# True omega: 1.663447, prediction by LW: -0.889965, num of resample calls: 16
# True omega: -3.073195, prediction by LW: -2.319638, num of resample calls: 16
# True omega: 0.031518, prediction by LW: -0.908551, num of resample calls: 17
# True omega: 0.848015, prediction by LW: -3.241614, num of resample calls: 16
# True omega: -2.908357, prediction by LW: -6.894360, num of resample calls: 17
# True omega: 1.646334, prediction by LW: -12.796095, num of resample calls: 17
# True omega: -2.173925, prediction by LW: -0.034696, num of resample calls: 16
# True omega: -0.409590, prediction by LW: 10.375502, num of resample calls: 17
# True omega: -2.540218, prediction by LW: -0.454790, num of resample calls: 17
# True omega: 0.770224, prediction by LW: 4.618110, num of resample calls: 17
# True omega: 1.444547, prediction by LW: -4.024705, num of resample calls: 16
# True omega: -0.242292, prediction by LW: 4.823263, num of resample calls: 16
# True omega: 1.464682, prediction by LW: 3.813804, num of resample calls: 17
# True omega: -1.540365, prediction by LW: 0.297464, num of resample calls: 16
# True omega: -1.940207, prediction by LW: 5.602345, num of resample calls: 17
# True omega: -2.931758, prediction by LW: 2.085580, num of resample calls: 17
# True omega: -0.341040, prediction by LW: 5.805963, num of resample calls: 16
# True omega: -1.138774, prediction by LW: 3.804055, num of resample calls: 17
# True omega: -1.993364, prediction by LW: 3.765639, num of resample calls: 17
# True omega: -1.164528, prediction by LW: -3.259110, num of resample calls: 17
# True omega: -2.110581, prediction by LW: 3.400871, num of resample calls: 17
# True omega: -2.515218, prediction by LW: -4.548536, num of resample calls: 17
# True omega: 1.202225, prediction by LW: -0.894616, num of resample calls: 17
# True omega: 3.092207, prediction by LW: -7.039748, num of resample calls: 17
# True omega: 0.886085, prediction by LW: 1.079470, num of resample calls: 16
# True omega: -0.007832, prediction by LW: -3.484116, num of resample calls: 16
# True omega: 2.818326, prediction by LW: -3.038703, num of resample calls: 16
# True omega: 1.761805, prediction by LW: -1.088615, num of resample calls: 17
# True omega: -0.005441, prediction by LW: 18.831027, num of resample calls: 16
# True omega: -1.645622, prediction by LW: -8.610889, num of resample calls: 17
# True omega: 1.340346, prediction by LW: -0.258640, num of resample calls: 16
# True omega: -2.191046, prediction by LW: 7.729158, num of resample calls: 17
# True omega: -3.092144, prediction by LW: 3.062474, num of resample calls: 16
# True omega: 0.571347, prediction by LW: -1.006955, num of resample calls: 16
# True omega: 1.609656, prediction by LW: 1.067879, num of resample calls: 17
# True omega: 0.317144, prediction by LW: 0.683253, num of resample calls: 17
# True omega: 1.595158, prediction by LW: 0.520294, num of resample calls: 17
# True omega: -2.911609, prediction by LW: 14.044899, num of resample calls: 16
# True omega: 2.632214, prediction by LW: -2.392266, num of resample calls: 17
# True omega: 0.137751, prediction by LW: 6.161807, num of resample calls: 17
# True omega: -1.298019, prediction by LW: 1.634266, num of resample calls: 17
# True omega: 2.155977, prediction by LW: -0.720261, num of resample calls: 16
# True omega: -2.997932, prediction by LW: -4.421302, num of resample calls: 17
# True omega: 1.891515, prediction by LW: 7.646800, num of resample calls: 17
# True omega: 1.400140, prediction by LW: -0.819473, num of resample calls: 16
# True omega: -2.149653, prediction by LW: 3.808705, num of resample calls: 16
# True omega: 0.503720, prediction by LW: 3.610911, num of resample calls: 17
# True omega: -0.311182, prediction by LW: 5.472148, num of resample calls: 17
# True omega: 1.043607, prediction by LW: 9.523733, num of resample calls: 17
# True omega: -0.561840, prediction by LW: -4.535763, num of resample calls: 17
# True omega: 1.436490, prediction by LW: -1.149664, num of resample calls: 17
# True omega: -0.244998, prediction by LW: 4.006092, num of resample calls: 17
# True omega: -1.814087, prediction by LW: -5.257814, num of resample calls: 16
# True omega: 2.557002, prediction by LW: -1.439727, num of resample calls: 16
# True omega: -0.800238, prediction by LW: -6.978047, num of resample calls: 17
# True omega: 2.728048, prediction by LW: -6.211676, num of resample calls: 17
# True omega: -1.374707, prediction by LW: 2.324293, num of resample calls: 16
# True omega: -2.547247, prediction by LW: 4.702359, num of resample calls: 17
# True omega: 2.024046, prediction by LW: 1.157500, num of resample calls: 17
# True omega: -1.575441, prediction by LW: -3.488180, num of resample calls: 17
# True omega: -1.719199, prediction by LW: -1.166146, num of resample calls: 17
# True omega: -2.901964, prediction by LW: 7.606158, num of resample calls: 16
# True omega: 0.034483, prediction by LW: -4.531517, num of resample calls: 16
# True omega: -0.657164, prediction by LW: -8.055402, num of resample calls: 17
# True omega: 2.223522, prediction by LW: -8.350032, num of resample calls: 16
# True omega: 0.566613, prediction by LW: -11.602557, num of resample calls: 17
# True omega: -2.070898, prediction by LW: 7.593299, num of resample calls: 16
# True omega: 0.023868, prediction by LW: -0.785305, num of resample calls: 17
# True omega: 0.169173, prediction by LW: -2.778028, num of resample calls: 16
# True omega: -0.263022, prediction by LW: -3.513336, num of resample calls: 16
# True omega: -2.358511, prediction by LW: 5.141665, num of resample calls: 16
# True omega: 1.939995, prediction by LW: -2.221946, num of resample calls: 17
# True omega: -1.364846, prediction by LW: -1.410971, num of resample calls: 17
# True omega: 2.172390, prediction by LW: 3.199289, num of resample calls: 16
# True omega: -0.911466, prediction by LW: 0.814313, num of resample calls: 16
# True omega: -0.066061, prediction by LW: 4.548078, num of resample calls: 17
# True omega: -0.646242, prediction by LW: 4.864543, num of resample calls: 17
# True omega: 1.587713, prediction by LW: -1.032840, num of resample calls: 17
# True omega: 3.058547, prediction by LW: 6.770427, num of resample calls: 16
# True omega: 2.942463, prediction by LW: 9.876294, num of resample calls: 16
# True omega: -0.898961, prediction by LW: -0.670078, num of resample calls: 16
# True omega: 1.403050, prediction by LW: 3.379776, num of resample calls: 16
# True omega: -1.402313, prediction by LW: -4.893633, num of resample calls: 17
# True omega: -1.110267, prediction by LW: 5.384275, num of resample calls: 16
# True omega: 1.318531, prediction by LW: -9.311832, num of resample calls: 16
# True omega: 1.069790, prediction by LW: -0.251630, num of resample calls: 17
# True omega: 0.647169, prediction by LW: 5.492494, num of resample calls: 16
# True omega: 0.509495, prediction by LW: -5.534808, num of resample calls: 16
# True omega: 1.199464, prediction by LW: -0.160563, num of resample calls: 16
# True omega: -2.154703, prediction by LW: -10.451662, num of resample calls: 17
# True omega: 2.464368, prediction by LW: 8.984498, num of resample calls: 17
# True omega: 1.802554, prediction by LW: 0.642656, num of resample calls: 17
# True omega: 1.017883, prediction by LW: -3.355189, num of resample calls: 17
# True omega: -1.326007, prediction by LW: -7.279313, num of resample calls: 17
# True omega: -3.123167, prediction by LW: -2.333042, num of resample calls: 17
# True omega: -1.614138, prediction by LW: -2.627556, num of resample calls: 16
# True omega: -0.966611, prediction by LW: -4.509169, num of resample calls: 17
# True omega: 1.058170, prediction by LW: -12.408903, num of resample calls: 17
# True omega: -2.482196, prediction by LW: -13.826693, num of resample calls: 17
# True omega: -2.967960, prediction by LW: -2.213814, num of resample calls: 16

# %%
lw_mse = np.mean( np.array(omega_star_list) - np.array(lw_pred_list)) ** 2
print(lw_mse)
# Out:
# 0.004967827418478848

# %%
lw_data_squared = (np.array(lw_data) - np.array(omega_star_list).reshape(-1,1)) ** 2 
lw_data_mean = np.mean(lw_data_squared, axis=0)
lw_data_median = np.median(lw_data_squared, axis =0)

num_data_points = lw_data_squared.shape[1]

plt.plot(np.arange(1,num_data_points+1, dtype=int), lw_data_mean, label='Mean')
plt.plot(np.arange(1,num_data_points+1, dtype=int), lw_data_median, label='Median')
plt.legend()
plt.title("LW")
plt.xlabel("Iters")
plt.ylabel("$(\omega - \omega*)^2$")
plt.yscale('log')
plt.show()
