# %%
import torch
import math
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torch.optim as optim
import matplotlib.pyplot as plt
import random
import scipy.stats
from tqdm import tqdm
from autoencoder_helper import gaussian_1d

seed = 10000
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

load = False

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
class Net(nn.Module):
    
    def __init__(self, n_input, n_output):
        super(Net, self).__init__()
        
        # encoder
        self.enc1 = nn.Linear(n_input,150, bias=False)
        self.enc2 = nn.Linear(150,100, bias=False)
        self.enc3 = nn.Linear(100,50, bias=False)
        self.enc4 = nn.Linear(50,10, bias=False)
        
        # decoder
        self.dec1 = nn.Linear(10, 50, bias=False)
        self.dec2 = nn.Linear(50, 100, bias=False)
        self.dec3 = nn.Linear(100, 150, bias=False)
        self.dec4 = nn.Linear(150, n_output, bias=False)
        

    def forward(self, x):
        x = torch.relu(self.enc1(x))
        x = torch.relu(self.enc2(x))
        x = torch.relu(self.enc3(x))
        x = torch.relu(self.enc4(x))
        x = torch.relu(self.dec1(x))
        x = torch.relu(self.dec2(x))
        x = torch.relu(self.dec3(x))
        x = self.dec4(x)
        return x

# %%
#generate training data of uni and bimodal Gaussians

n_input = 200
n_output = n_input # n_output == n_input for autoencoders

n_train_data = 20000
n_test_data = 2000
train_data = np.empty((0,n_input), float)
test_data = np.empty((0,n_input), float)

for i in tqdm(range(n_train_data)):
    
    # unimodal 2d train data
    mean = np.random.uniform(-10,10, size=2)
    cov = np.eye(2)
    cov[0,0] = np.random.uniform(1,2)
    cov[1,1] = np.random.uniform(1,2)
    data = np.random.multivariate_normal(mean, cov, size=100)
    sortidxs = np.argsort(np.linalg.norm(data, axis=1))
    data = data[sortidxs]
    means =  np.mean(data, axis=0)
    stds = np.std(data, axis=0)
    data = np.divide(data - means, stds)
    data = data.reshape(1,-1)
    train_data = np.append(train_data, data, axis=0)

    # unimodal 2d test data
for i in tqdm(range(n_test_data)):
    
    mean = np.random.uniform(-10,10, size=2)
    cov = np.eye(2)
    cov[0,0] = np.random.uniform(1,2)
    cov[1,1] = np.random.uniform(1,2)
    data = np.random.multivariate_normal(mean, cov, size=100)
    sortidxs = np.argsort(np.linalg.norm(data, axis=1))
    data = data[sortidxs]
    means =  np.mean(data, axis=0)
    stds = np.std(data, axis=0)
    data = np.divide(data - means,stds)
    data = data.reshape(1,-1)
    test_data = np.append(test_data, data, axis=0)
    
#     #bimodal train data
#     mean1 = random.uniform(-10,10)
#     mean2 = random.uniform(-10,10)
#     std1 = random.uniform(1,3)
#     std2 = random.uniform(1,3)
#     x1 = np.random.normal(mean1, std1, size=(1,n_input//2))
#     x2 = np.random.normal(mean2, std2, size=(1,n_input//2))
#     bi_data1 = np.concatenate([x1,x2], axis =1)
#     train_data = np.append(train_data, bi_data1, axis= 0)
    
#     #bimodal test data
#     mean1 = random.uniform(-10,10)
#     mean2 = random.uniform(-10,10)
#     std1 = random.uniform(1,3)
#     std2 = random.uniform(1,3)
#     x1 = np.random.normal(mean1, std1, size=(1,n_input//2))
#     x2 = np.random.normal(mean2, std2, size=(1,n_input//2))
#     bi_data2 = np.concatenate([x1,x2], axis =1)
#     test_data = np.append(test_data, bi_data2, axis=0)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 20000/20000 [01:03<00:00, 315.94it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 2000/2000 [00:00<00:00, 2013.66it/s]

# %%
train_data = train_data.astype(np.float32)
train_data = torch.from_numpy(train_data)
train_data = train_data.to(device)

test_data = test_data.astype(np.float32)
test_data = torch.from_numpy(test_data)
test_data = test_data.to(device)

# %%
epochs_end = 20000
epochs_start = 0
# batch_size = 32
# n_batch = n_train_data//batch_size
net = Net(n_input, n_output)
net = net.to(device)
optimizer = optim.Adam(net.parameters(), lr=0.001)
loss_func = nn.MSELoss()
net.train()
# Out:
# Net(
#   (enc1): Linear(in_features=200, out_features=150, bias=True)
#   (enc2): Linear(in_features=150, out_features=100, bias=True)
#   (enc3): Linear(in_features=100, out_features=50, bias=True)
#   (enc4): Linear(in_features=50, out_features=10, bias=True)
#   (dec1): Linear(in_features=10, out_features=50, bias=True)
#   (dec2): Linear(in_features=50, out_features=100, bias=True)
#   (dec3): Linear(in_features=100, out_features=150, bias=True)
#   (dec4): Linear(in_features=150, out_features=200, bias=True)
# )

# %%
if load:
    net = Net(n_input, n_output)
    net = net.to(device)
    checkpoint = torch.load('model_ll_dropout_lr_0.001.pt')
    net.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    epochs_start = checkpoint['epoch']

# %%
# for e in range(epochs_start, epochs_end):

#     print("Current epoch number: {}".format(e))
#     for i in range(n_batch):
#         mini_batch_data = train_data[i*batch_size:(i+1)*batch_size, :]
#         mini_batch_data = mini_batch_data.to(device)
#         prediction = net(mini_batch_data)
#         #loss = likelihood_loss(prediction, i) 
#         loss = loss_func(prediction, mini_batch_data)
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
    
#     if (e+1) % 10 == 0 :
#         net.eval()
#         train_pred = net(train_data)
#         #loss = likelihood_loss(full_pred, -1, train=False)
#         loss = loss_func(train_pred, train_data)
#         train_loss = loss.item()
        
#         test_pred = net(test_data)
#         #loss = likelihood_loss(full_pred, -1, train=False)
#         loss = loss_func(test_pred, test_data)
#         test_loss = loss.item()
#         net.train()
        
#         print("Epoch {:d}, train loss: {:f}, test loss: {:f}".format(e,train_loss,test_loss))
# #         torch.save({
# #             'epoch': e,
# #             'model_state_dict': net.state_dict(),
# #             'optimizer_state_dict': optimizer.state_dict()
# #         }, 'model.pt')

# %%
for e in range(epochs_start, epochs_end):

    prediction = net(train_data)
    loss = loss_func(prediction, train_data)
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (e+1) % 100 == 0 :
        net.eval()
        print("Current epoch number: {}".format(e))
        test_pred = net(test_data)
        loss = loss_func(test_pred, test_data)
        test_loss = loss.item()
        
        train_pred = net(train_data)
        loss = loss_func(train_pred, train_data)
        train_loss = loss.item()
        net.train()
        
        print("Epoch {:d}, train loss: {:f}, test loss: {:f}".format(e,train_loss,test_loss))
#         torch.save({
#             'epoch': e,
#             'model_state_dict': net.state_dict(),
#             'optimizer_state_dict': optimizer.state_dict(),
#             'test_loss': test_loss,
#             'train_loss': train_loss
#         }, 'model_mse_dropout_2d_lr_0.001.pt')
# Out:
# Current epoch number: 99
# Epoch 99, train loss: 0.523423, test loss: 0.522192
# Current epoch number: 199
# Epoch 199, train loss: 0.522527, test loss: 0.521423
# Current epoch number: 299
# Epoch 299, train loss: 0.519419, test loss: 0.518329
# Current epoch number: 399
# Epoch 399, train loss: 0.514870, test loss: 0.513948
# Current epoch number: 499
# Epoch 499, train loss: 0.512373, test loss: 0.512016
# Current epoch number: 599
# Epoch 599, train loss: 0.509442, test loss: 0.509601
# Current epoch number: 699
# Epoch 699, train loss: 0.504999, test loss: 0.505643
# Current epoch number: 799
# Epoch 799, train loss: 0.501369, test loss: 0.502728
# Current epoch number: 899
# Epoch 899, train loss: 0.499791, test loss: 0.501718
# Current epoch number: 999
# Epoch 999, train loss: 0.498358, test loss: 0.500863
# Current epoch number: 1099
# Epoch 1099, train loss: 0.497456, test loss: 0.500467
# Current epoch number: 1199
# Epoch 1199, train loss: 0.496871, test loss: 0.500305
# Current epoch number: 1299
# Epoch 1299, train loss: 0.495981, test loss: 0.499842
# Current epoch number: 1399
# Epoch 1399, train loss: 0.495914, test loss: 0.500113
# Current epoch number: 1499
# Epoch 1499, train loss: 0.495014, test loss: 0.499627
# Current epoch number: 1599
# Epoch 1599, train loss: 0.494425, test loss: 0.499414
# Current epoch number: 1699
# Epoch 1699, train loss: 0.494023, test loss: 0.499311
# Current epoch number: 1799
# Epoch 1799, train loss: 0.494124, test loss: 0.499736
# Current epoch number: 1899
# Epoch 1899, train loss: 0.493192, test loss: 0.499161
# Current epoch number: 1999
# Epoch 1999, train loss: 0.492982, test loss: 0.499247
# Current epoch number: 2099
# Epoch 2099, train loss: 0.492404, test loss: 0.499026
# Current epoch number: 2199
# Epoch 2199, train loss: 0.492183, test loss: 0.499154
# Current epoch number: 2299
# Epoch 2299, train loss: 0.491888, test loss: 0.499178
# Current epoch number: 2399
# Epoch 2399, train loss: 0.491494, test loss: 0.499099
# Current epoch number: 2499
# Epoch 2499, train loss: 0.491095, test loss: 0.498989
# Current epoch number: 2599
# Epoch 2599, train loss: 0.490778, test loss: 0.499021
# Current epoch number: 2699
# Epoch 2699, train loss: 0.490754, test loss: 0.499261
# Current epoch number: 2799
# Epoch 2799, train loss: 0.490201, test loss: 0.499102
# Current epoch number: 2899
# Epoch 2899, train loss: 0.489813, test loss: 0.499037
# Current epoch number: 2999
# Epoch 2999, train loss: 0.489361, test loss: 0.498922
# Current epoch number: 3099
# Epoch 3099, train loss: 0.489092, test loss: 0.498944
# Current epoch number: 3199
# Epoch 3199, train loss: 0.488786, test loss: 0.498962
# Current epoch number: 3299
# Epoch 3299, train loss: 0.488364, test loss: 0.498810
# Current epoch number: 3399
# Epoch 3399, train loss: 0.488749, test loss: 0.499586
# Current epoch number: 3499
# Epoch 3499, train loss: 0.487731, test loss: 0.498819
# Current epoch number: 3599
# Epoch 3599, train loss: 0.487837, test loss: 0.499226
# Current epoch number: 3699
# Epoch 3699, train loss: 0.487138, test loss: 0.498843
# Current epoch number: 3799
# Epoch 3799, train loss: 0.486772, test loss: 0.498716
# Current epoch number: 3899
# Epoch 3899, train loss: 0.486618, test loss: 0.498893
# Current epoch number: 3999
# Epoch 3999, train loss: 0.485966, test loss: 0.498637
# Current epoch number: 4099
# Epoch 4099, train loss: 0.485734, test loss: 0.498705
# Current epoch number: 4199
# Epoch 4199, train loss: 0.485549, test loss: 0.498733
# Current epoch number: 4299
# Epoch 4299, train loss: 0.485148, test loss: 0.498636
# Current epoch number: 4399
# Epoch 4399, train loss: 0.485078, test loss: 0.498845
# Current epoch number: 4499
# Epoch 4499, train loss: 0.484606, test loss: 0.498699
# Current epoch number: 4599
# Epoch 4599, train loss: 0.484194, test loss: 0.498574
# Current epoch number: 4699
# Epoch 4699, train loss: 0.484213, test loss: 0.498818
# Current epoch number: 4799
# Epoch 4799, train loss: 0.483951, test loss: 0.498813
# Current epoch number: 4899
# Epoch 4899, train loss: 0.483706, test loss: 0.498845
# Current epoch number: 4999
# Epoch 4999, train loss: 0.483413, test loss: 0.498787
# Current epoch number: 5099
# Epoch 5099, train loss: 0.483711, test loss: 0.499255
# Current epoch number: 5199
# Epoch 5199, train loss: 0.483374, test loss: 0.499111
# Current epoch number: 5299
# Epoch 5299, train loss: 0.483001, test loss: 0.499246
# Current epoch number: 5399
# Epoch 5399, train loss: 0.482830, test loss: 0.499233
# Current epoch number: 5499
# Epoch 5499, train loss: 0.482667, test loss: 0.499380
# Current epoch number: 5599
# Epoch 5599, train loss: 0.482523, test loss: 0.499534
# Current epoch number: 5699
# Epoch 5699, train loss: 0.482284, test loss: 0.499455
# Current epoch number: 5799
# Epoch 5799, train loss: 0.482063, test loss: 0.499643
# Current epoch number: 5899
# Epoch 5899, train loss: 0.481899, test loss: 0.499698
# Current epoch number: 5999
# Epoch 5999, train loss: 0.482231, test loss: 0.500052
# Current epoch number: 6099
# Epoch 6099, train loss: 0.481886, test loss: 0.500150
# Current epoch number: 6199
# Epoch 6199, train loss: 0.481648, test loss: 0.500300
# Current epoch number: 6299
# Epoch 6299, train loss: 0.481710, test loss: 0.500665
# Current epoch number: 6399
# Epoch 6399, train loss: 0.481380, test loss: 0.500616
# Current epoch number: 6499
# Epoch 6499, train loss: 0.481287, test loss: 0.500756
# Current epoch number: 6599
# Epoch 6599, train loss: 0.481260, test loss: 0.501042
# Current epoch number: 6699
# Epoch 6699, train loss: 0.481113, test loss: 0.501139
# Current epoch number: 6799
# Epoch 6799, train loss: 0.480874, test loss: 0.501307
# Current epoch number: 6899
# Epoch 6899, train loss: 0.480949, test loss: 0.501483
# Current epoch number: 6999
# Epoch 6999, train loss: 0.480624, test loss: 0.501594
# Current epoch number: 7099
# Epoch 7099, train loss: 0.480688, test loss: 0.501735
# Current epoch number: 7199
# Epoch 7199, train loss: 0.480900, test loss: 0.502101
# Current epoch number: 7299
# Epoch 7299, train loss: 0.480390, test loss: 0.502053
# Current epoch number: 7399
# Epoch 7399, train loss: 0.480623, test loss: 0.502440
# Current epoch number: 7499
# Epoch 7499, train loss: 0.480382, test loss: 0.502650
# Current epoch number: 7599
# Epoch 7599, train loss: 0.480196, test loss: 0.502715
# Current epoch number: 7699
# Epoch 7699, train loss: 0.480139, test loss: 0.502894
# Current epoch number: 7799
# Epoch 7799, train loss: 0.480069, test loss: 0.502878
# Current epoch number: 7899
# Epoch 7899, train loss: 0.480104, test loss: 0.503109
# Current epoch number: 7999
# Epoch 7999, train loss: 0.480117, test loss: 0.503209
# Current epoch number: 8099
# Epoch 8099, train loss: 0.479771, test loss: 0.503501
# Current epoch number: 8199
# Epoch 8199, train loss: 0.479785, test loss: 0.503778
# Current epoch number: 8299
# Epoch 8299, train loss: 0.479771, test loss: 0.503809
# Current epoch number: 8399
# Epoch 8399, train loss: 0.479457, test loss: 0.503674
# Current epoch number: 8499
# Epoch 8499, train loss: 0.479441, test loss: 0.503958
# Current epoch number: 8599
# Epoch 8599, train loss: 0.479472, test loss: 0.504136
# Current epoch number: 8699
# Epoch 8699, train loss: 0.479431, test loss: 0.504190
# Current epoch number: 8799
# Epoch 8799, train loss: 0.479281, test loss: 0.504140
# Current epoch number: 8899
# Epoch 8899, train loss: 0.479096, test loss: 0.504083
# Current epoch number: 8999
# Epoch 8999, train loss: 0.479037, test loss: 0.504171
# Current epoch number: 9099
# Epoch 9099, train loss: 0.479113, test loss: 0.504458
# Current epoch number: 9199
# Epoch 9199, train loss: 0.478791, test loss: 0.504607
# Current epoch number: 9299
# Epoch 9299, train loss: 0.478934, test loss: 0.504915
# Current epoch number: 9399
# Epoch 9399, train loss: 0.478817, test loss: 0.505031
# Current epoch number: 9499
# Epoch 9499, train loss: 0.478874, test loss: 0.505220
# Current epoch number: 9599
# Epoch 9599, train loss: 0.478672, test loss: 0.505330
# Current epoch number: 9699
# Epoch 9699, train loss: 0.478740, test loss: 0.505542
# Current epoch number: 9799
# Epoch 9799, train loss: 0.478694, test loss: 0.505719
# Current epoch number: 9899
# Epoch 9899, train loss: 0.478384, test loss: 0.505697
# Current epoch number: 9999
# Epoch 9999, train loss: 0.478676, test loss: 0.506205
# Current epoch number: 10099
# Epoch 10099, train loss: 0.478498, test loss: 0.505803
# Current epoch number: 10199
# Epoch 10199, train loss: 0.478319, test loss: 0.505997
# Current epoch number: 10299
# Epoch 10299, train loss: 0.478350, test loss: 0.506056
# Current epoch number: 10399
# Epoch 10399, train loss: 0.478061, test loss: 0.506226
# Current epoch number: 10499
# Epoch 10499, train loss: 0.478472, test loss: 0.506215
# Current epoch number: 10599
# Epoch 10599, train loss: 0.478540, test loss: 0.506647
# Current epoch number: 10699
# Epoch 10699, train loss: 0.477907, test loss: 0.506546
# Current epoch number: 10799
# Epoch 10799, train loss: 0.477881, test loss: 0.506602
# Current epoch number: 10899
# Epoch 10899, train loss: 0.478089, test loss: 0.506757
# Current epoch number: 10999
# Epoch 10999, train loss: 0.477885, test loss: 0.506520
# Current epoch number: 11099
# Epoch 11099, train loss: 0.477938, test loss: 0.506569
# Current epoch number: 11199
# Epoch 11199, train loss: 0.477831, test loss: 0.506655
# Current epoch number: 11299
# Epoch 11299, train loss: 0.477994, test loss: 0.506787
# Current epoch number: 11399
# Epoch 11399, train loss: 0.477784, test loss: 0.506737
# Current epoch number: 11499
# Epoch 11499, train loss: 0.477760, test loss: 0.506890
# Current epoch number: 11599
# Epoch 11599, train loss: 0.477412, test loss: 0.506750
# Current epoch number: 11699
# Epoch 11699, train loss: 0.477415, test loss: 0.506801
# Current epoch number: 11799
# Epoch 11799, train loss: 0.477555, test loss: 0.507035
# Current epoch number: 11899
# Epoch 11899, train loss: 0.477396, test loss: 0.507040
# Current epoch number: 11999
# Epoch 11999, train loss: 0.477477, test loss: 0.507454
# Current epoch number: 12099
# Epoch 12099, train loss: 0.477357, test loss: 0.507420
# Current epoch number: 12199
# Epoch 12199, train loss: 0.477204, test loss: 0.507565
# Current epoch number: 12299
# Epoch 12299, train loss: 0.477143, test loss: 0.507393
# Current epoch number: 12399
# Epoch 12399, train loss: 0.477169, test loss: 0.507538
# Current epoch number: 12499
# Epoch 12499, train loss: 0.477079, test loss: 0.507417
# Current epoch number: 12599
# Epoch 12599, train loss: 0.477209, test loss: 0.507976
# Current epoch number: 12699
# Epoch 12699, train loss: 0.477296, test loss: 0.507784
# Current epoch number: 12799
# Epoch 12799, train loss: 0.476945, test loss: 0.507724
# Current epoch number: 12899
# Epoch 12899, train loss: 0.476920, test loss: 0.507888
# Current epoch number: 12999
# Epoch 12999, train loss: 0.477109, test loss: 0.507830
# Current epoch number: 13099
# Epoch 13099, train loss: 0.476991, test loss: 0.508087
# Current epoch number: 13199
# Epoch 13199, train loss: 0.476799, test loss: 0.507976
# Current epoch number: 13299
# Epoch 13299, train loss: 0.477140, test loss: 0.508110
# Current epoch number: 13399
# Epoch 13399, train loss: 0.477064, test loss: 0.508234
# Current epoch number: 13499
# Epoch 13499, train loss: 0.476900, test loss: 0.508492
# Current epoch number: 13599
# Epoch 13599, train loss: 0.477011, test loss: 0.508712
# Current epoch number: 13699
# Epoch 13699, train loss: 0.476826, test loss: 0.508514
# Current epoch number: 13799
# Epoch 13799, train loss: 0.476720, test loss: 0.508521
# Current epoch number: 13899
# Epoch 13899, train loss: 0.476500, test loss: 0.508482
# Current epoch number: 13999
# Epoch 13999, train loss: 0.476613, test loss: 0.508621
# Current epoch number: 14099
# Epoch 14099, train loss: 0.476472, test loss: 0.508511
# Current epoch number: 14199
# Epoch 14199, train loss: 0.476586, test loss: 0.508697
# Current epoch number: 14299
# Epoch 14299, train loss: 0.476565, test loss: 0.508703
# Current epoch number: 14399
# Epoch 14399, train loss: 0.476427, test loss: 0.508820
# Current epoch number: 14499
# Epoch 14499, train loss: 0.476376, test loss: 0.508849
# Current epoch number: 14599
# Epoch 14599, train loss: 0.476318, test loss: 0.508932
# Current epoch number: 14699
# Epoch 14699, train loss: 0.476282, test loss: 0.509120
# Current epoch number: 14799
# Epoch 14799, train loss: 0.476279, test loss: 0.509048
# Current epoch number: 14899
# Epoch 14899, train loss: 0.476246, test loss: 0.509171
# Current epoch number: 14999
# Epoch 14999, train loss: 0.476041, test loss: 0.509126
# Current epoch number: 15099
# Epoch 15099, train loss: 0.476141, test loss: 0.509466
# Current epoch number: 15199
# Epoch 15199, train loss: 0.476365, test loss: 0.509268
# Current epoch number: 15299
# Epoch 15299, train loss: 0.476341, test loss: 0.509486
# Current epoch number: 15399
# Epoch 15399, train loss: 0.476186, test loss: 0.509586
# Current epoch number: 15499
# Epoch 15499, train loss: 0.475954, test loss: 0.509589
# Current epoch number: 15599
# Epoch 15599, train loss: 0.476105, test loss: 0.509584
# Current epoch number: 15699
# Epoch 15699, train loss: 0.475953, test loss: 0.509565
# Current epoch number: 15799
# Epoch 15799, train loss: 0.476086, test loss: 0.509785
# Current epoch number: 15899
# Epoch 15899, train loss: 0.476008, test loss: 0.509834
# Current epoch number: 15999
# Epoch 15999, train loss: 0.476011, test loss: 0.509942
# Current epoch number: 16099
# Epoch 16099, train loss: 0.476276, test loss: 0.510078
# Current epoch number: 16199
# Epoch 16199, train loss: 0.475911, test loss: 0.510073
# Current epoch number: 16299
# Epoch 16299, train loss: 0.475797, test loss: 0.510208
# Current epoch number: 16399
# Epoch 16399, train loss: 0.475895, test loss: 0.510183
# Current epoch number: 16499
# Epoch 16499, train loss: 0.475713, test loss: 0.510298
# Current epoch number: 16599
# Epoch 16599, train loss: 0.475668, test loss: 0.510216
# Current epoch number: 16699
# Epoch 16699, train loss: 0.475705, test loss: 0.510402
# Current epoch number: 16799
# Epoch 16799, train loss: 0.475746, test loss: 0.510471
# Current epoch number: 16899
# Epoch 16899, train loss: 0.475506, test loss: 0.510464
# Current epoch number: 16999
# Epoch 16999, train loss: 0.475727, test loss: 0.510596
# Current epoch number: 17099
# Epoch 17099, train loss: 0.475454, test loss: 0.510584
# Current epoch number: 17199
# Epoch 17199, train loss: 0.475612, test loss: 0.510719
# Current epoch number: 17299
# Epoch 17299, train loss: 0.475633, test loss: 0.510883
# Current epoch number: 17399
# Epoch 17399, train loss: 0.475714, test loss: 0.510825
# Current epoch number: 17499
# Epoch 17499, train loss: 0.475203, test loss: 0.510750
# Current epoch number: 17599
# Epoch 17599, train loss: 0.475595, test loss: 0.511037
# Current epoch number: 17699
# Epoch 17699, train loss: 0.475753, test loss: 0.511007
# Current epoch number: 17799
# Epoch 17799, train loss: 0.475339, test loss: 0.511061
# Current epoch number: 17899
# Epoch 17899, train loss: 0.475363, test loss: 0.511141
# Current epoch number: 17999
# Epoch 17999, train loss: 0.475422, test loss: 0.511177
# Current epoch number: 18099
# Epoch 18099, train loss: 0.475423, test loss: 0.511285
# Current epoch number: 18199
# Epoch 18199, train loss: 0.475183, test loss: 0.511147
# Current epoch number: 18299
# Epoch 18299, train loss: 0.475071, test loss: 0.511307
# Current epoch number: 18399
# Epoch 18399, train loss: 0.475360, test loss: 0.511272
# Current epoch number: 18499
# Epoch 18499, train loss: 0.475159, test loss: 0.511493
# Current epoch number: 18599
# Epoch 18599, train loss: 0.475196, test loss: 0.511429
# Current epoch number: 18699
# Epoch 18699, train loss: 0.474973, test loss: 0.511336
# Current epoch number: 18799
# Epoch 18799, train loss: 0.475471, test loss: 0.511728
# Current epoch number: 18899
# Epoch 18899, train loss: 0.475183, test loss: 0.511585
# Current epoch number: 18999
# Epoch 18999, train loss: 0.475194, test loss: 0.512113
# Current epoch number: 19099
# Epoch 19099, train loss: 0.474991, test loss: 0.511834
# Current epoch number: 19199
# Epoch 19199, train loss: 0.474970, test loss: 0.512109
# Current epoch number: 19299
# Epoch 19299, train loss: 0.474901, test loss: 0.511981
# Current epoch number: 19399
# Epoch 19399, train loss: 0.474924, test loss: 0.512305
# Current epoch number: 19499
# Epoch 19499, train loss: 0.474878, test loss: 0.512413
# Current epoch number: 19599
# Epoch 19599, train loss: 0.474769, test loss: 0.512039
# Current epoch number: 19699
# Epoch 19699, train loss: 0.475158, test loss: 0.512396
# Current epoch number: 19799
# Epoch 19799, train loss: 0.474833, test loss: 0.512579
# Current epoch number: 19899
# Epoch 19899, train loss: 0.474927, test loss: 0.512452
# Current epoch number: 19999
# Epoch 19999, train loss: 0.474900, test loss: 0.512474

# %%
net.eval()
pred = net(test_data)
pred_data = pred.detach().cpu().numpy().reshape(n_test_data,-1,2)
x_pred = pred_data[:,:,0]
y_pred = pred_data[:,:,1]

# %%
for i in np.arange(0,1000,21):
    
    x_test, y_test = test_data[i].cpu().numpy().reshape(-1,2).T
    plt.plot(x_test, y_test, 'x')
    plt.plot(x_pred[i], y_pred[i], 'x')
    plt.axis('equal')
    plt.show()
