# %%
import torch
import math
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torch.optim as optim
import matplotlib.pyplot as plt
import random
import scipy.stats
from tqdm import tqdm
from autoencoder_helper import gaussian_1d

seed = 10000
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

load = False

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
class Net(nn.Module):
    
    def __init__(self):
        super(Net, self).__init__()
        
        self.conv1d1 = nn.Conv1d(in_channels=1,out_channels=1, kernel_size=2, bias=False) # output is shape (N x 1 x 196)
        self.pool1d1 = nn.MaxPool1d(kernel_size=2, return_indices=True) # output is shape (N x 1 x 49)
#         self.conv1d2 = nn.Conv1d(in_channels=1, out_channels=1, kernel_size=4) # output is shape (N x 1 x 46)
#         self.pool1d2 = nn.MaxPool1d(kernel_size=2, return_indices=True) # output is shape (N x 1 x 23)
        self.linear1 = nn.Linear(99, 50, bias=False)
        self.linear2 = nn.Linear(50,10, bias=False)
        self.linear3 = nn.Linear(10,50, bias=False)
        self.linear4 = nn.Linear(50,99, bias=False)
#         self.unpool1d1 = nn.MaxUnpool1d(kernel_size=2)
#         self.conv1dtranspose1 = nn.ConvTranspose1d(in_channels=1, out_channels=1 , kernel_size=4)
        self.unpool1d2 = nn.MaxUnpool1d(kernel_size=2)
        self.conv1dtranspose2 = nn.ConvTranspose1d(in_channels=1, out_channels=1, kernel_size=3, bias=False)
        
        self.bn1 = nn.BatchNorm1d(1)
        self.bn2 = nn.BatchNorm1d(1)
        self.bn3 = nn.BatchNorm1d(1)
        self.bn4 = nn.BatchNorm1d(1)
        
    def forward(self, x):
        x = self.conv1d1(x)
        x, indices1 = self.pool1d1(x)
        #print(x.shape)
#         x = self.conv1d2(x)
#         x, indices2 = self.pool1d2(x)
        x = torch.relu(self.bn1(self.linear1(x)))
        x = torch.relu(self.bn2(self.linear2(x)))
        x = torch.relu(self.bn3(self.linear3(x)))
        x = torch.relu(self.bn4(self.linear4(x)))
#         x = torch.relu(self.linear1(x))
#         x = torch.relu(self.linear2(x))
#         x = torch.relu(self.linear3(x))
#         x = torch.relu(self.linear4(x))
#         x = self.unpool1d1(x, indices2)
#         x = self.conv1dtranspose1(x)
        x = self.unpool1d2(x, indices1)
        x = self.conv1dtranspose2(x)
        #print(x.shape)
        return x

# %%
#generate training data of uni and bimodal Gaussians

n_input = 200
n_output = n_input # n_output == n_input for autoencoders

n_train_data = 20000
n_test_data = 2000
train_data = np.empty((0,n_input), float)
test_data = np.empty((0,n_input), float)

for i in tqdm(range(n_train_data)):
    
    # unimodal 2d train data
    mean = np.random.uniform(-10,10, size=2)
    cov = np.eye(2)
    cov[0,0] = np.random.uniform(1,2)
    cov[1,1] = np.random.uniform(1,2)
    data = np.random.multivariate_normal(mean, cov, size=100)
    sortidxs = np.argsort(np.linalg.norm(data, axis=1))
    data = data[sortidxs]
    means =  np.mean(data, axis=0)
    stds = np.std(data, axis=0)
    data = np.divide(data - means, stds)
    data = data.reshape(1,-1)
    train_data = np.append(train_data, data, axis=0)

    # unimodal 2d test data
for i in tqdm(range(n_test_data)):
    
    mean = np.random.uniform(-10,10, size=2)
    cov = np.eye(2)
    cov[0,0] = np.random.uniform(1,2)
    cov[1,1] = np.random.uniform(1,2)
    data = np.random.multivariate_normal(mean, cov, size=100)
    sortidxs = np.argsort(np.linalg.norm(data, axis=1))
    data = data[sortidxs]
    means =  np.mean(data, axis=0)
    stds = np.std(data, axis=0)
    data = np.divide(data - means,stds)
    data = data.reshape(1,-1)
    test_data = np.append(test_data, data, axis=0)
    
#     #bimodal train data
#     mean1 = random.uniform(-10,10)
#     mean2 = random.uniform(-10,10)
#     std1 = random.uniform(1,3)
#     std2 = random.uniform(1,3)
#     x1 = np.random.normal(mean1, std1, size=(1,n_input//2))
#     x2 = np.random.normal(mean2, std2, size=(1,n_input//2))
#     bi_data1 = np.concatenate([x1,x2], axis =1)
#     train_data = np.append(train_data, bi_data1, axis= 0)
    
#     #bimodal test data
#     mean1 = random.uniform(-10,10)
#     mean2 = random.uniform(-10,10)
#     std1 = random.uniform(1,3)
#     std2 = random.uniform(1,3)
#     x1 = np.random.normal(mean1, std1, size=(1,n_input//2))
#     x2 = np.random.normal(mean2, std2, size=(1,n_input//2))
#     bi_data2 = np.concatenate([x1,x2], axis =1)
#     test_data = np.append(test_data, bi_data2, axis=0)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 20000/20000 [01:01<00:00, 327.57it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 2000/2000 [00:00<00:00, 2004.12it/s]

# %%
train_data = train_data.astype(np.float32)
train_data = torch.from_numpy(train_data)
train_data = train_data.to(device)

test_data = test_data.astype(np.float32)
test_data = torch.from_numpy(test_data)
test_data = test_data.to(device)

# %%
epochs_end = 600
epochs_start = 0
batch_size = 8
n_batch = n_train_data//batch_size
net = Net()
net = net.to(device)
optimizer = optim.Adam(net.parameters(), lr=0.001)
loss_func = nn.MSELoss()
net.train()
# Out:
# Net(
#   (conv1d1): Conv1d(1, 1, kernel_size=(2,), stride=(1,), bias=False)
#   (pool1d1): MaxPool1d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (linear1): Linear(in_features=99, out_features=50, bias=False)
#   (linear2): Linear(in_features=50, out_features=10, bias=False)
#   (linear3): Linear(in_features=10, out_features=50, bias=False)
#   (linear4): Linear(in_features=50, out_features=99, bias=False)
#   (unpool1d2): MaxUnpool1d(kernel_size=(2,), stride=(2,), padding=(0,))
#   (conv1dtranspose2): ConvTranspose1d(1, 1, kernel_size=(3,), stride=(1,), bias=False)
# )

# %%
# if load:
#     net = Net(n_input, n_output)
#     net = net.to(device)
#     checkpoint = torch.load('model_ll_dropout_lr_0.001.pt')
#     net.load_state_dict(checkpoint['model_state_dict'])
#     optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
#     epochs_start = checkpoint['epoch']

# %%
def batch_eval(model, data, batch_size, n_batch):
    tot_loss = 0
    for i in range(n_batch):
        mini_batch_data = data[i*batch_size:(i+1)*batch_size, :]
        mini_batch_data = mini_batch_data.to(device)
        mini_batch_data = mini_batch_data.view(batch_size, 1, 200)
        prediction = model(mini_batch_data)
        loss = loss_func(prediction, mini_batch_data)
        tot_loss += loss.item()
        
    return tot_loss/n_batch

# %%
for e in range(epochs_start, epochs_end):

    print("Current epoch number: {}".format(e))
    for i in range(n_batch):
        mini_batch_data = train_data[i*batch_size:(i+1)*batch_size, :]
        mini_batch_data = mini_batch_data.view(batch_size, 1, 200)
        mini_batch_data = mini_batch_data.to(device)
        prediction = net(mini_batch_data)
        loss = loss_func(prediction, mini_batch_data)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    if (e+1) % 10 == 0 :
        net.eval()
        train_loss = batch_eval(net, train_data, batch_size, n_batch)
        test_loss = batch_eval(net, test_data, batch_size, 2000//batch_size)
        net.train()
        
        print("Epoch {:d}, train loss: {:f}, test loss: {:f}".format(e,train_loss,test_loss))
#         torch.save({
#             'epoch': e,
#             'model_state_dict': net.state_dict(),
#             'optimizer_state_dict': optimizer.state_dict()
#         }, 'model.pt')
# Out:
# Current epoch number: 0
# Current epoch number: 1
# Current epoch number: 2
# Current epoch number: 3
# Current epoch number: 4
# Current epoch number: 5
# Current epoch number: 6
# Current epoch number: 7
# Current epoch number: 8
# Current epoch number: 9
# Epoch 9, train loss: 0.669615, test loss: 0.669438
# Current epoch number: 10
# Current epoch number: 11
# Current epoch number: 12
# Current epoch number: 13
# Current epoch number: 14
# Current epoch number: 15
# Current epoch number: 16
# Current epoch number: 17
# Current epoch number: 18
# Current epoch number: 19
# Epoch 19, train loss: 0.655858, test loss: 0.655669
# Current epoch number: 20
# Current epoch number: 21
# Current epoch number: 22
# Current epoch number: 23
# Current epoch number: 24
# Current epoch number: 25
# Current epoch number: 26
# Current epoch number: 27
# Current epoch number: 28
# Current epoch number: 29
# Epoch 29, train loss: 0.652211, test loss: 0.652281
# Current epoch number: 30
# Current epoch number: 31
# Current epoch number: 32
# Current epoch number: 33
# Current epoch number: 34
# Current epoch number: 35
# Current epoch number: 36
# Current epoch number: 37
# Current epoch number: 38
# Current epoch number: 39
# Epoch 39, train loss: 0.652180, test loss: 0.652297
# Current epoch number: 40
# Current epoch number: 41
# Current epoch number: 42
# Current epoch number: 43
# Current epoch number: 44
# Current epoch number: 45
# Current epoch number: 46
# Current epoch number: 47
# Current epoch number: 48
# Current epoch number: 49
# Epoch 49, train loss: 0.651962, test loss: 0.652121
# Current epoch number: 50
# Current epoch number: 51
# Current epoch number: 52
# Current epoch number: 53
# Current epoch number: 54
# Current epoch number: 55
# Current epoch number: 56
# Current epoch number: 57
# Current epoch number: 58
# Current epoch number: 59
# Epoch 59, train loss: 0.648095, test loss: 0.648025
# Current epoch number: 60
# Current epoch number: 61
# Current epoch number: 62
# Current epoch number: 63
# Current epoch number: 64
# Current epoch number: 65
# Current epoch number: 66
# Current epoch number: 67
# Current epoch number: 68
# Current epoch number: 69
# Epoch 69, train loss: 0.645356, test loss: 0.645612
# Current epoch number: 70
# Current epoch number: 71
# Current epoch number: 72
# Current epoch number: 73
# Current epoch number: 74
# Current epoch number: 75
# Current epoch number: 76
# Current epoch number: 77
# Current epoch number: 78
# Current epoch number: 79
# Epoch 79, train loss: 0.643425, test loss: 0.643704
# Current epoch number: 80
# Current epoch number: 81
# Current epoch number: 82
# Current epoch number: 83
# Current epoch number: 84
# Current epoch number: 85
# Current epoch number: 86
# Current epoch number: 87
# Current epoch number: 88
# Current epoch number: 89
# Epoch 89, train loss: 0.642512, test loss: 0.642821
# Current epoch number: 90
# Current epoch number: 91
# Current epoch number: 92
# Current epoch number: 93
# Current epoch number: 94
# Current epoch number: 95
# Current epoch number: 96
# Current epoch number: 97
# Current epoch number: 98
# Current epoch number: 99
# Epoch 99, train loss: 0.640076, test loss: 0.640532
# Current epoch number: 100
# Current epoch number: 101
# Current epoch number: 102
# Current epoch number: 103
# Current epoch number: 104
# Current epoch number: 105
# Current epoch number: 106
# Current epoch number: 107
# Current epoch number: 108
# Current epoch number: 109
# Epoch 109, train loss: 0.637623, test loss: 0.638200
# Current epoch number: 110
# Current epoch number: 111
# Current epoch number: 112
# Current epoch number: 113
# Current epoch number: 114
# Current epoch number: 115
# Current epoch number: 116
# Current epoch number: 117
# Current epoch number: 118
# Current epoch number: 119
# Epoch 119, train loss: 0.631654, test loss: 0.632243
# Current epoch number: 120
# Current epoch number: 121
# Current epoch number: 122
# Current epoch number: 123
# Current epoch number: 124
# Current epoch number: 125
# Current epoch number: 126
# Current epoch number: 127
# Current epoch number: 128
# Current epoch number: 129
# Epoch 129, train loss: 0.631432, test loss: 0.632076
# Current epoch number: 130
# Current epoch number: 131
# Current epoch number: 132
# Current epoch number: 133
# Current epoch number: 134
# Current epoch number: 135
# Current epoch number: 136
# Current epoch number: 137
# Current epoch number: 138
# Current epoch number: 139
# Epoch 139, train loss: 0.631201, test loss: 0.631861
# Current epoch number: 140
# Current epoch number: 141
# Current epoch number: 142
# Current epoch number: 143
# Current epoch number: 144
# Current epoch number: 145
# Current epoch number: 146
# Current epoch number: 147
# Current epoch number: 148
# Current epoch number: 149
# Epoch 149, train loss: 0.631123, test loss: 0.631770
# Current epoch number: 150
# Current epoch number: 151
# Current epoch number: 152
# Current epoch number: 153
# Current epoch number: 154
# Current epoch number: 155
# Current epoch number: 156
# Current epoch number: 157
# Current epoch number: 158
# Current epoch number: 159
# Epoch 159, train loss: 0.631161, test loss: 0.631885
# Current epoch number: 160
# Current epoch number: 161
# Current epoch number: 162
# Current epoch number: 163
# Current epoch number: 164
# Current epoch number: 165
# Current epoch number: 166
# Current epoch number: 167
# Current epoch number: 168
# Current epoch number: 169
# Epoch 169, train loss: 0.631124, test loss: 0.631870
# Current epoch number: 170
# Current epoch number: 171
# Current epoch number: 172
# Current epoch number: 173
# Current epoch number: 174
# Current epoch number: 175
# Current epoch number: 176
# Current epoch number: 177
# Current epoch number: 178
# Current epoch number: 179
# Epoch 179, train loss: 0.631071, test loss: 0.631778
# Current epoch number: 180
# Current epoch number: 181
# Current epoch number: 182
# Current epoch number: 183
# Current epoch number: 184
# Current epoch number: 185
# Current epoch number: 186
# Current epoch number: 187
# Current epoch number: 188
# Current epoch number: 189
# Epoch 189, train loss: 0.630925, test loss: 0.631685
# Current epoch number: 190
# Current epoch number: 191
# Current epoch number: 192
# Current epoch number: 193
# Current epoch number: 194
# Current epoch number: 195
# Current epoch number: 196
# Current epoch number: 197
# Current epoch number: 198
# Current epoch number: 199
# Epoch 199, train loss: 0.630771, test loss: 0.631642
# Current epoch number: 200
# Current epoch number: 201
# Current epoch number: 202
# Current epoch number: 203
# Current epoch number: 204
# Current epoch number: 205
# Current epoch number: 206
# Current epoch number: 207
# Current epoch number: 208
# Current epoch number: 209
# Epoch 209, train loss: 0.630650, test loss: 0.631499
# Current epoch number: 210
# Current epoch number: 211
# Current epoch number: 212
# Current epoch number: 213
# Current epoch number: 214
# Current epoch number: 215
# Current epoch number: 216
# Current epoch number: 217
# Current epoch number: 218
# Current epoch number: 219
# Epoch 219, train loss: 0.631425, test loss: 0.631937
# Current epoch number: 220
# Current epoch number: 221
# Current epoch number: 222
# Current epoch number: 223
# Current epoch number: 224
# Current epoch number: 225
# Current epoch number: 226
# Current epoch number: 227
# Current epoch number: 228
# Current epoch number: 229
# Epoch 229, train loss: 0.630876, test loss: 0.631817
# Current epoch number: 230
# Current epoch number: 231
# Current epoch number: 232
# Current epoch number: 233
# Current epoch number: 234
# Current epoch number: 235
# Current epoch number: 236
# Current epoch number: 237
# Current epoch number: 238
# Current epoch number: 239
# Epoch 239, train loss: 0.631023, test loss: 0.631857
# Current epoch number: 240
# Current epoch number: 241
# Current epoch number: 242
# Current epoch number: 243
# Current epoch number: 244
# Current epoch number: 245
# Current epoch number: 246
# Current epoch number: 247
# Current epoch number: 248
# Current epoch number: 249
# Epoch 249, train loss: 0.631001, test loss: 0.631931
# Current epoch number: 250
# Current epoch number: 251
# Current epoch number: 252
# Current epoch number: 253
# Current epoch number: 254
# Current epoch number: 255
# Current epoch number: 256
# Current epoch number: 257
# Current epoch number: 258
# Current epoch number: 259
# Epoch 259, train loss: 0.630631, test loss: 0.631573
# Current epoch number: 260
# Current epoch number: 261
# Current epoch number: 262
# Current epoch number: 263
# Current epoch number: 264
# Current epoch number: 265
# Current epoch number: 266
# Current epoch number: 267
# Current epoch number: 268
# Current epoch number: 269
# Epoch 269, train loss: 0.631187, test loss: 0.632093
# Current epoch number: 270
# Current epoch number: 271
# Current epoch number: 272
# Current epoch number: 273
# Current epoch number: 274
# Current epoch number: 275
# Current epoch number: 276
# Current epoch number: 277
# Current epoch number: 278
# Current epoch number: 279
# Epoch 279, train loss: 0.631294, test loss: 0.632179
# Current epoch number: 280
# Current epoch number: 281
# Current epoch number: 282
# Current epoch number: 283
# Current epoch number: 284
# Current epoch number: 285
# Current epoch number: 286
# Current epoch number: 287
# Current epoch number: 288
# Current epoch number: 289
# Epoch 289, train loss: 0.630712, test loss: 0.631642
# Current epoch number: 290
# Current epoch number: 291
# Current epoch number: 292
# Current epoch number: 293
# Current epoch number: 294
# Current epoch number: 295
# Current epoch number: 296
# Current epoch number: 297
# Current epoch number: 298
# Current epoch number: 299
# Epoch 299, train loss: 0.630449, test loss: 0.631427
# Current epoch number: 300
# Current epoch number: 301
# Current epoch number: 302
# Current epoch number: 303
# Current epoch number: 304
# Current epoch number: 305
# Current epoch number: 306
# Current epoch number: 307
# Current epoch number: 308
# Current epoch number: 309
# Epoch 309, train loss: 0.630543, test loss: 0.631549
# Current epoch number: 310
# Current epoch number: 311
# Current epoch number: 312
# Current epoch number: 313
# Current epoch number: 314
# Current epoch number: 315
# Current epoch number: 316
# Current epoch number: 317
# Current epoch number: 318
# Current epoch number: 319
# Epoch 319, train loss: 0.630652, test loss: 0.631657
# Current epoch number: 320
# Current epoch number: 321
# Current epoch number: 322
# Current epoch number: 323
# Current epoch number: 324
# Current epoch number: 325
# Current epoch number: 326
# Current epoch number: 327
# Current epoch number: 328
# Current epoch number: 329
# Epoch 329, train loss: 0.630500, test loss: 0.631603
# Current epoch number: 330
# Current epoch number: 331
# Current epoch number: 332
# Current epoch number: 333
# Current epoch number: 334
# Current epoch number: 335
# Current epoch number: 336
# Current epoch number: 337
# Current epoch number: 338
# Current epoch number: 339
# Epoch 339, train loss: 0.630397, test loss: 0.631405
# Current epoch number: 340
# Current epoch number: 341
# Current epoch number: 342
# Current epoch number: 343
# Current epoch number: 344
# Current epoch number: 345
# Current epoch number: 346
# Current epoch number: 347
# Current epoch number: 348
# Current epoch number: 349
# Epoch 349, train loss: 0.630446, test loss: 0.631501
# Current epoch number: 350
# Current epoch number: 351
# Current epoch number: 352
# Current epoch number: 353
# Current epoch number: 354
# Current epoch number: 355
# Current epoch number: 356
# Current epoch number: 357
# Current epoch number: 358
# Current epoch number: 359
# Epoch 359, train loss: 0.630495, test loss: 0.631613
# Current epoch number: 360
# Current epoch number: 361
# Current epoch number: 362
# Current epoch number: 363
# Current epoch number: 364
# Current epoch number: 365
# Current epoch number: 366
# Current epoch number: 367
# Current epoch number: 368
# Current epoch number: 369
# Epoch 369, train loss: 0.630459, test loss: 0.631468
# Current epoch number: 370
# Current epoch number: 371
# Current epoch number: 372
# Current epoch number: 373
# Current epoch number: 374
# Current epoch number: 375
# Current epoch number: 376
# Current epoch number: 377
# Current epoch number: 378
# Current epoch number: 379
# Epoch 379, train loss: 0.630923, test loss: 0.631911
# Current epoch number: 380
# Current epoch number: 381
# Current epoch number: 382
# Current epoch number: 383
# Current epoch number: 384
# Current epoch number: 385
# Current epoch number: 386
# Current epoch number: 387
# Current epoch number: 388
# Current epoch number: 389
# Epoch 389, train loss: 0.630308, test loss: 0.631213
# Current epoch number: 390
# Current epoch number: 391
# Current epoch number: 392
# Current epoch number: 393
# Current epoch number: 394
# Current epoch number: 395
# Current epoch number: 396
# Current epoch number: 397
# Current epoch number: 398
# Current epoch number: 399
# Epoch 399, train loss: 0.630377, test loss: 0.631381
# Current epoch number: 400
# Current epoch number: 401
# Current epoch number: 402
# Current epoch number: 403
# Current epoch number: 404
# Current epoch number: 405
# Current epoch number: 406
# Current epoch number: 407
# Current epoch number: 408
# Current epoch number: 409
# Epoch 409, train loss: 0.630618, test loss: 0.631633
# Current epoch number: 410
# Current epoch number: 411
# Current epoch number: 412
# Current epoch number: 413
# Current epoch number: 414
# Current epoch number: 415
# Current epoch number: 416
# Current epoch number: 417
# Current epoch number: 418
# Current epoch number: 419
# Epoch 419, train loss: 0.630505, test loss: 0.631439
# Current epoch number: 420
# Current epoch number: 421
# Current epoch number: 422
# Current epoch number: 423
# Current epoch number: 424
# Current epoch number: 425
# Current epoch number: 426
# Current epoch number: 427
# Current epoch number: 428
# Current epoch number: 429
# Epoch 429, train loss: 0.630456, test loss: 0.631188
# Current epoch number: 430
# Current epoch number: 431
# Current epoch number: 432
# Current epoch number: 433
# Current epoch number: 434
# Current epoch number: 435
# Current epoch number: 436
# Current epoch number: 437
# Current epoch number: 438
# Current epoch number: 439
# Epoch 439, train loss: 0.630463, test loss: 0.631483
# Current epoch number: 440
# Current epoch number: 441
# Current epoch number: 442
# Current epoch number: 443
# Current epoch number: 444
# Current epoch number: 445
# Current epoch number: 446
# Current epoch number: 447
# Current epoch number: 448
# Current epoch number: 449
# Epoch 449, train loss: 0.630187, test loss: 0.631141
# Current epoch number: 450
# Current epoch number: 451
# Current epoch number: 452
# Current epoch number: 453
# Current epoch number: 454
# Current epoch number: 455
# Current epoch number: 456
# Current epoch number: 457
# Current epoch number: 458
# Current epoch number: 459
# Epoch 459, train loss: 0.630577, test loss: 0.631371
# Current epoch number: 460
# Current epoch number: 461
# Current epoch number: 462
# Current epoch number: 463
# Current epoch number: 464
# Current epoch number: 465
# Current epoch number: 466
# Current epoch number: 467
# Current epoch number: 468
# Current epoch number: 469
# Epoch 469, train loss: 0.630769, test loss: 0.631349
# Current epoch number: 470
# Current epoch number: 471
# Current epoch number: 472
# Current epoch number: 473
# Current epoch number: 474
# Current epoch number: 475
# Current epoch number: 476
# Current epoch number: 477
# Current epoch number: 478
# Current epoch number: 479
# Epoch 479, train loss: 0.630256, test loss: 0.631207
# Current epoch number: 480
# Current epoch number: 481
# Current epoch number: 482
# Current epoch number: 483
# Current epoch number: 484
# Current epoch number: 485
# Current epoch number: 486
# Current epoch number: 487
# Current epoch number: 488
# Current epoch number: 489
# Epoch 489, train loss: 0.630343, test loss: 0.631375
# Current epoch number: 490
# Current epoch number: 491
# Current epoch number: 492
# Current epoch number: 493
# Current epoch number: 494
# Current epoch number: 495
# Current epoch number: 496
# Current epoch number: 497
# Current epoch number: 498
# Current epoch number: 499
# Epoch 499, train loss: 0.630240, test loss: 0.631288
# Current epoch number: 500
# Current epoch number: 501
# Current epoch number: 502
# Current epoch number: 503
# Current epoch number: 504
# Current epoch number: 505
# Current epoch number: 506
# Current epoch number: 507
# Current epoch number: 508
# Current epoch number: 509
# Epoch 509, train loss: 0.630195, test loss: 0.631178
# Current epoch number: 510
# Current epoch number: 511
# Current epoch number: 512
# Current epoch number: 513
# Current epoch number: 514
# Current epoch number: 515
# Current epoch number: 516
# Current epoch number: 517
# Current epoch number: 518
# Current epoch number: 519
# Epoch 519, train loss: 0.630322, test loss: 0.631310
# Current epoch number: 520
# Current epoch number: 521
# Current epoch number: 522
# Current epoch number: 523
# Current epoch number: 524
# Current epoch number: 525
# Current epoch number: 526
# Current epoch number: 527
# Current epoch number: 528
# Current epoch number: 529
# Epoch 529, train loss: 0.629962, test loss: 0.631054
# Current epoch number: 530
# Current epoch number: 531
# Current epoch number: 532
# Current epoch number: 533
# Current epoch number: 534
# Current epoch number: 535
# Current epoch number: 536
# Current epoch number: 537
# Current epoch number: 538
# Current epoch number: 539
# Epoch 539, train loss: 0.630268, test loss: 0.631311
# Current epoch number: 540
# Current epoch number: 541
# Current epoch number: 542
# Current epoch number: 543
# Current epoch number: 544
# Current epoch number: 545
# Current epoch number: 546
# Current epoch number: 547
# Current epoch number: 548
# Current epoch number: 549
# Epoch 549, train loss: 0.629887, test loss: 0.630985
# Current epoch number: 550
# Current epoch number: 551
# Current epoch number: 552
# Current epoch number: 553
# Current epoch number: 554
# Current epoch number: 555
# Current epoch number: 556
# Current epoch number: 557
# Current epoch number: 558
# Current epoch number: 559
# Epoch 559, train loss: 0.630049, test loss: 0.631103
# Current epoch number: 560
# Current epoch number: 561
# Current epoch number: 562
# Current epoch number: 563
# Current epoch number: 564
# Current epoch number: 565
# Current epoch number: 566
# Current epoch number: 567
# Current epoch number: 568
# Current epoch number: 569
# Epoch 569, train loss: 0.630045, test loss: 0.631112
# Current epoch number: 570
# Current epoch number: 571
# Current epoch number: 572
# Current epoch number: 573
# Current epoch number: 574
# Current epoch number: 575
# Current epoch number: 576
# Current epoch number: 577
# Current epoch number: 578
# Current epoch number: 579
# Epoch 579, train loss: 0.629975, test loss: 0.631064
# Current epoch number: 580
# Current epoch number: 581
# Current epoch number: 582
# Current epoch number: 583
# Current epoch number: 584
# Current epoch number: 585
# Current epoch number: 586
# Current epoch number: 587
# Current epoch number: 588
# Current epoch number: 589
# Epoch 589, train loss: 0.629900, test loss: 0.630918
# Current epoch number: 590
# Current epoch number: 591
# Current epoch number: 592
# Current epoch number: 593
# Current epoch number: 594
# Current epoch number: 595
# Current epoch number: 596
# Current epoch number: 597
# Current epoch number: 598
# Current epoch number: 599
# Epoch 599, train loss: 0.630160, test loss: 0.631229
# Current epoch number: 600
# Current epoch number: 601
# Current epoch number: 602
# Current epoch number: 603
# Current epoch number: 604
# Current epoch number: 605
# Current epoch number: 606
# Current epoch number: 607
# Current epoch number: 608
# Current epoch number: 609
# Epoch 609, train loss: 0.630213, test loss: 0.631169
# Current epoch number: 610
# Current epoch number: 611
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-e75402893e0d> in <module>
#       9         loss = loss_func(prediction, mini_batch_data)
#      10         optimizer.zero_grad()
# ---> 11         loss.backward()
#      12         optimizer.step()
#      13
#
# ~\anaconda3\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~\anaconda3\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     128         retain_graph = create_graph
#     129
# --> 130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
#     132         allow_unreachable=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
# for e in range(epochs_start, epochs_end):

#     prediction = net(train_data.view(20000,1,200))
#     loss = loss_func(prediction, train_data)
#     optimizer.zero_grad()
#     loss.backward()
#     optimizer.step()

#     if (e+1) % 100 == 0 :
#         net.eval()
#         print("Current epoch number: {}".format(e))
#         test_pred = net(test_data)
#         loss = loss_func(test_pred, test_data)
#         test_loss = loss.item()
        
#         train_pred = net(train_data)
#         loss = loss_func(train_pred, train_data)
#         train_loss = loss.item()
#         net.train()
        
#         print("Epoch {:d}, train loss: {:f}, test loss: {:f}".format(e,train_loss,test_loss))
# #         torch.save({
# #             'epoch': e,
# #             'model_state_dict': net.state_dict(),
# #             'optimizer_state_dict': optimizer.state_dict(),
# #             'test_loss': test_loss,
# #             'train_loss': train_loss
# #         }, 'model_mse_dropout_2d_lr_0.001.pt')

# %%
net.eval()
pred = net(test_data.view(n_test_data,1,200))
pred_data = pred.detach().cpu().numpy().reshape(n_test_data,-1,2)
x_pred = pred_data[:,:,0]
y_pred = pred_data[:,:,1]

for i in np.arange(0,1000,21):
    
    x_test, y_test = test_data[i].cpu().numpy().reshape(-1,2).T
    plt.plot(x_test, y_test, 'x')
    plt.plot(x_pred[i], y_pred[i], 'x')
    plt.axis('equal')
    plt.show()

# %%
pred = net(train_data.view(n_train_data,1,200))
pred_data = pred.detach().cpu().numpy().reshape(n_train_data,-1,2)
x_pred = pred_data[:,:,0]
y_pred = pred_data[:,:,1]

for i in np.arange(0,1000,21):
    
    x_train, y_train = train_data[i].cpu().numpy().reshape(-1,2).T
    plt.plot(x_train, y_train, 'x')
    plt.plot(x_pred[i], y_pred[i], 'x')
    plt.axis('equal')
    plt.show()
