# %%
import torch
import math
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import torch.optim as optim
import matplotlib.pyplot as plt
import random
import scipy.stats
from tqdm import tqdm
from autoencoder_helper import gaussian_1d

seed = 10000
torch.manual_seed(seed)
np.random.seed(seed)
random.seed(seed)

load = False

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
class Net(nn.Module):
    
    def __init__(self, n_input, n_output):
        super(Net, self).__init__()
        
        # encoder
        self.enc1 = nn.Linear(n_input,50)
        self.enc2 = nn.Linear(50,25)
        self.enc3 = nn.Linear(25,10)
        
        # decoder
        self.dec1 = nn.Linear(10, 25)
        self.dec2 = nn.Linear(25, 50)
        self.dec3 = nn.Linear(50, n_output)
        
        self.dropout = nn.Dropout(p=0.5)
        
#     def forward(self, x):
#         x = torch.sigmoid(self.enc1(x)) 
#         x = torch.sigmoid(self.enc2(x))
#         x = torch.sigmoid(self.enc3(x))
#         x = torch.sigmoid(self.enc4(x))
        
#         x = torch.sigmoid(self.dec1(x))
#         x = torch.sigmoid(self.dec2(x))
#         x = torch.sigmoid(self.dec3(x))
#         x = self.dec4(x)
#         return x

    def forward(self, x):
        x = self.dropout(torch.relu(self.enc1(x)))
        x = self.dropout(torch.relu(self.enc2(x)))
        x = self.dropout(torch.relu(self.enc3(x)))
        x = self.dropout(torch.relu(self.dec1(x)))
        x = self.dropout(torch.relu(self.dec2(x)))
        x = self.dec3(x)
        return x

# %%
#generate training data of uni and bimodal Gaussians

n_input = 200
n_output = n_input # n_output == n_input for autoencoders

n_train_data = 20000
train_data = np.empty((0,n_input), float)
test_data = np.empty((0,n_input), float)

for i in tqdm(range(n_train_data)):
    
    # unimodal train data
    mean1 = random.uniform(-10,10)
    std1 = random.uniform(1,3)
    uni_data1 = np.random.normal(mean1, std1, size = (1,n_input))
    train_data = np.append(train_data, uni_data1, axis = 0 )
    
    # unimodal test data
    mean2 = random.uniform(-10,10)
    std2 = random.uniform(1,3)
    uni_data2 = np.random.normal(mean2, std2, size = (1,n_input))
    test_data = np.append(test_data, uni_data2, axis = 0 )
    
#     #bimodal train data
#     mean1 = random.uniform(-10,10)
#     mean2 = random.uniform(-10,10)
#     std1 = random.uniform(1,3)
#     std2 = random.uniform(1,3)
#     x1 = np.random.normal(mean1, std1, size=(1,n_input//2))
#     x2 = np.random.normal(mean2, std2, size=(1,n_input//2))
#     bi_data1 = np.concatenate([x1,x2], axis =1)
#     train_data = np.append(train_data, bi_data1, axis= 0)
    
#     #bimodal test data
#     mean1 = random.uniform(-10,10)
#     mean2 = random.uniform(-10,10)
#     std1 = random.uniform(1,3)
#     std2 = random.uniform(1,3)
#     x1 = np.random.normal(mean1, std1, size=(1,n_input//2))
#     x2 = np.random.normal(mean2, std2, size=(1,n_input//2))
#     bi_data2 = np.concatenate([x1,x2], axis =1)
#     test_data = np.append(test_data, bi_data2, axis=0)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 20000/20000 [02:44<00:00, 121.90it/s]

# %%
train_data = train_data.astype(np.float32)
train_data = np.sort(train_data, axis=1)
train_mean = np.mean(train_data, axis=1)
train_std = np.std(train_data, axis=1)
train_data = torch.from_numpy(train_data)
train_data = train_data.to(device)
for i in range(train_data.shape[0]):
    train_data[i,:] = (train_data[i,:] - train_mean[i] ) / train_std[i]

test_data = test_data.astype(np.float32)
test_data = np.sort(test_data, axis=1)
test_mean = np.mean(test_data, axis=1)
test_std = np.std(test_data, axis=1)
test_data = torch.from_numpy(test_data)
test_data = test_data.to(device)
for i in range(train_data.shape[0]):
    test_data[i,:] = (test_data[i,:] - test_mean[i] ) / test_std[i]

# %%
epochs_end = 10000
epochs_start = 0
batch_size = 32
n_batch = n_train_data//batch_size
net = Net(n_input, n_output)
net = net.to(device)
optimizer = optim.Adam(net.parameters(), lr=0.001)
loss_func = nn.MSELoss()
net.train()
# Out:
# Net(
#   (enc1): Linear(in_features=200, out_features=50, bias=True)
#   (enc2): Linear(in_features=50, out_features=25, bias=True)
#   (enc3): Linear(in_features=25, out_features=10, bias=True)
#   (dec1): Linear(in_features=10, out_features=25, bias=True)
#   (dec2): Linear(in_features=25, out_features=50, bias=True)
#   (dec3): Linear(in_features=50, out_features=200, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
if load:
    net = Net(n_input, n_output)
    net = net.to(device)
    checkpoint = torch.load('model_ll_dropout_lr_0.001.pt')
    net.load_state_dict(checkpoint['model_state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer_state_dict'])
    epochs_start = checkpoint['epoch']

# %%
# for e in range(epochs_start, epochs_end):

#     print("Current epoch number: {}".format(e))
#     for i in range(n_batch):
#         mini_batch_data = train_data[i*batch_size:(i+1)*batch_size, :]
#         mini_batch_data = mini_batch_data.to(device)
#         prediction = net(mini_batch_data)
#         #loss = likelihood_loss(prediction, i) 
#         loss = loss_func(prediction, mini_batch_data)
#         optimizer.zero_grad()
#         loss.backward()
#         optimizer.step()
    
#     if (e+1) % 10 == 0 :
#         net.eval()
#         train_pred = net(train_data)
#         #loss = likelihood_loss(full_pred, -1, train=False)
#         loss = loss_func(train_pred, train_data)
#         train_loss = loss.item()
        
#         test_pred = net(test_data)
#         #loss = likelihood_loss(full_pred, -1, train=False)
#         loss = loss_func(test_pred, test_data)
#         test_loss = loss.item()
#         net.train()
        
#         print("Epoch {:d}, train loss: {:f}, test loss: {:f}".format(e,train_loss,test_loss))
# #         torch.save({
# #             'epoch': e,
# #             'model_state_dict': net.state_dict(),
# #             'optimizer_state_dict': optimizer.state_dict()
# #         }, 'model.pt')

# %%
for e in range(epochs_start, epochs_end):

    prediction = net(train_data)
    loss = loss_func(prediction, train_data)
    train_loss = loss.item()
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (e+1) % 100 == 0 :
        net.eval()
        print("Current epoch number: {}".format(e))
        test_pred = net(test_data)
        loss = loss_func(test_pred, test_data)
        test_loss = loss.item()
        net.train()
        
        print("Epoch {:d}, train loss: {:f}, test loss: {:f}".format(e,train_loss,test_loss))
#         torch.save({
#             'epoch': e,
#             'model_state_dict': net.state_dict(),
#             'optimizer_state_dict': optimizer.state_dict(),
#             'test_loss': test_loss,
#             'train_loss': train_loss
#         }, 'model_ll_dropout_lr_0.001.pt')
# Out:
# Current epoch number: 99
# Epoch 99, train loss: 23.417681, test loss: 27.812136
# Current epoch number: 199
# Epoch 199, train loss: 21.479954, test loss: 28.305693
# Current epoch number: 299
# Epoch 299, train loss: 19.100027, test loss: 26.231724
# Current epoch number: 399
# Epoch 399, train loss: 14.138244, test loss: 21.705702
# Current epoch number: 499
# Epoch 499, train loss: 11.812896, test loss: 19.554955
# Current epoch number: 599
# Epoch 599, train loss: 10.879886, test loss: 17.034124
# Current epoch number: 699
# Epoch 699, train loss: 10.464015, test loss: 16.353870
# Current epoch number: 799
# Epoch 799, train loss: 9.995014, test loss: 15.426428
# Current epoch number: 899
# Epoch 899, train loss: 9.606630, test loss: 15.530940
# Current epoch number: 999
# Epoch 999, train loss: 9.722026, test loss: 15.274320
# Current epoch number: 1099
# Epoch 1099, train loss: 9.364496, test loss: 14.758885
# Current epoch number: 1199
# Epoch 1199, train loss: 9.046858, test loss: 14.508386
# Current epoch number: 1299
# Epoch 1299, train loss: 8.904997, test loss: 14.678318
# Current epoch number: 1399
# Epoch 1399, train loss: 8.785478, test loss: 13.750510
# Current epoch number: 1499
# Epoch 1499, train loss: 8.425764, test loss: 13.679162
# Current epoch number: 1599
# Epoch 1599, train loss: 8.348214, test loss: 13.451887
# Current epoch number: 1699
# Epoch 1699, train loss: 8.444798, test loss: 12.838677
# Current epoch number: 1799
# Epoch 1799, train loss: 8.167302, test loss: 13.527322
# Current epoch number: 1899
# Epoch 1899, train loss: 8.001951, test loss: 13.040312
# Current epoch number: 1999
# Epoch 1999, train loss: 7.569569, test loss: 12.442690
# Current epoch number: 2099
# Epoch 2099, train loss: 7.471976, test loss: 12.206979
# Current epoch number: 2199
# Epoch 2199, train loss: 7.207569, test loss: 11.714378
# Current epoch number: 2299
# Epoch 2299, train loss: 7.201783, test loss: 11.429438
# Current epoch number: 2399
# Epoch 2399, train loss: 7.007172, test loss: 10.962318
# Current epoch number: 2499
# Epoch 2499, train loss: 6.926368, test loss: 10.962698
# Current epoch number: 2599
# Epoch 2599, train loss: 6.874213, test loss: 11.071558
# Current epoch number: 2699
# Epoch 2699, train loss: 6.972215, test loss: 11.607599
# Current epoch number: 2799
# Epoch 2799, train loss: 6.882390, test loss: 11.246515
# Current epoch number: 2899
# Epoch 2899, train loss: 6.902266, test loss: 11.563910
# Current epoch number: 2999
# Epoch 2999, train loss: 6.830663, test loss: 11.912064
# Current epoch number: 3099
# Epoch 3099, train loss: 6.748711, test loss: 11.483564
# Current epoch number: 3199
# Epoch 3199, train loss: 6.737843, test loss: 11.369986
# Current epoch number: 3299
# Epoch 3299, train loss: 6.717652, test loss: 11.352517
# Current epoch number: 3399
# Epoch 3399, train loss: 6.804780, test loss: 12.261684
# Current epoch number: 3499
# Epoch 3499, train loss: 6.571424, test loss: 11.525708
# Current epoch number: 3599
# Epoch 3599, train loss: 6.615574, test loss: 11.787390
# Current epoch number: 3699
# Epoch 3699, train loss: 6.590730, test loss: 11.946175
# Current epoch number: 3799
# Epoch 3799, train loss: 6.504160, test loss: 11.089700
# Current epoch number: 3899
# Epoch 3899, train loss: 6.573465, test loss: 11.077778
# Current epoch number: 3999
# Epoch 3999, train loss: 6.358076, test loss: 10.897336
# Current epoch number: 4099
# Epoch 4099, train loss: 6.230892, test loss: 10.536361
# Current epoch number: 4199
# Epoch 4199, train loss: 6.242918, test loss: 10.376422
# Current epoch number: 4299
# Epoch 4299, train loss: 6.075964, test loss: 10.473697
# Current epoch number: 4399
# Epoch 4399, train loss: 6.001581, test loss: 10.184981
# Current epoch number: 4499
# Epoch 4499, train loss: 5.968820, test loss: 10.675942
# Current epoch number: 4599
# Epoch 4599, train loss: 5.988856, test loss: 9.882256
# Current epoch number: 4699
# Epoch 4699, train loss: 6.060267, test loss: 10.289938
# Current epoch number: 4799
# Epoch 4799, train loss: 5.966602, test loss: 10.140220
# Current epoch number: 4899
# Epoch 4899, train loss: 5.735669, test loss: 9.730192
# Current epoch number: 4999
# Epoch 4999, train loss: 5.707694, test loss: 9.573398
# Current epoch number: 5099
# Epoch 5099, train loss: 5.660942, test loss: 10.054782
# Current epoch number: 5199
# Epoch 5199, train loss: 5.821490, test loss: 9.356460
# Current epoch number: 5299
# Epoch 5299, train loss: 5.693786, test loss: 9.873605
# Current epoch number: 5399
# Epoch 5399, train loss: 5.605707, test loss: 10.378535
# Current epoch number: 5499
# Epoch 5499, train loss: 5.667878, test loss: 9.694376
# Current epoch number: 5599
# Epoch 5599, train loss: 5.862827, test loss: 10.409066
# Current epoch number: 5699
# Epoch 5699, train loss: 5.719644, test loss: 9.662494
# Current epoch number: 5799
# Epoch 5799, train loss: 5.696492, test loss: 9.911902
# Current epoch number: 5899
# Epoch 5899, train loss: 5.453652, test loss: 9.649037
# Current epoch number: 5999
# Epoch 5999, train loss: 5.500807, test loss: 9.619417
# Current epoch number: 6099
# Epoch 6099, train loss: 5.740713, test loss: 9.482089
# Current epoch number: 6199
# Epoch 6199, train loss: 5.441176, test loss: 9.755975
# Current epoch number: 6299
# Epoch 6299, train loss: 5.513923, test loss: 9.365322
# Current epoch number: 6399
# Epoch 6399, train loss: 5.468624, test loss: 9.746534
# Current epoch number: 6499
# Epoch 6499, train loss: 5.442583, test loss: 9.460901
# Current epoch number: 6599
# Epoch 6599, train loss: 5.656717, test loss: 10.084794
# Current epoch number: 6699
# Epoch 6699, train loss: 5.392135, test loss: 9.569894
# Current epoch number: 6799
# Epoch 6799, train loss: 5.440383, test loss: 9.577193
# Current epoch number: 6899
# Epoch 6899, train loss: 5.210416, test loss: 9.463512
# Current epoch number: 6999
# Epoch 6999, train loss: 5.243783, test loss: 9.916440
# Current epoch number: 7099
# Epoch 7099, train loss: 5.436339, test loss: 10.024236
# Current epoch number: 7199
# Epoch 7199, train loss: 5.259829, test loss: 9.691424
# Current epoch number: 7299
# Epoch 7299, train loss: 5.230519, test loss: 9.363841
# Current epoch number: 7399
# Epoch 7399, train loss: 5.238166, test loss: 9.646940
# Current epoch number: 7499
# Epoch 7499, train loss: 5.225867, test loss: 10.029696
# Current epoch number: 7599
# Epoch 7599, train loss: 5.144447, test loss: 9.247034
# Current epoch number: 7699
# Epoch 7699, train loss: 5.375208, test loss: 9.648493
# Current epoch number: 7799
# Epoch 7799, train loss: 5.179313, test loss: 9.781802
# Current epoch number: 7899
# Epoch 7899, train loss: 5.378385, test loss: 9.460093
# Current epoch number: 7999
# Epoch 7999, train loss: 5.247717, test loss: 9.948444
# Current epoch number: 8099
# Epoch 8099, train loss: 5.077758, test loss: 9.578908
# Current epoch number: 8199
# Epoch 8199, train loss: 5.110050, test loss: 9.946546
# Current epoch number: 8299
# Epoch 8299, train loss: 5.130989, test loss: 9.575366
# Current epoch number: 8399
# Epoch 8399, train loss: 5.085926, test loss: 9.843428
# Current epoch number: 8499
# Epoch 8499, train loss: 5.076505, test loss: 9.681406
# Current epoch number: 8599
# Epoch 8599, train loss: 5.066629, test loss: 9.505402
# Current epoch number: 8699
# Epoch 8699, train loss: 4.989829, test loss: 9.802687
# Current epoch number: 8799
# Epoch 8799, train loss: 5.025909, test loss: 9.561808
# Current epoch number: 8899
# Epoch 8899, train loss: 5.176384, test loss: 9.325161
# Current epoch number: 8999
# Epoch 8999, train loss: 5.102760, test loss: 9.901808
# Current epoch number: 9099
# Epoch 9099, train loss: 5.069323, test loss: 9.686429
# Current epoch number: 9199
# Epoch 9199, train loss: 5.478196, test loss: 9.613381
# Current epoch number: 9299
# Epoch 9299, train loss: 5.123370, test loss: 9.574468
# Current epoch number: 9399
# Epoch 9399, train loss: 5.088439, test loss: 9.347388
# Current epoch number: 9499
# Epoch 9499, train loss: 5.067323, test loss: 9.493454
# Current epoch number: 9599
# Epoch 9599, train loss: 5.126109, test loss: 9.864886
# Current epoch number: 9699
# Epoch 9699, train loss: 5.043417, test loss: 9.527448
# Current epoch number: 9799
# Epoch 9799, train loss: 4.980203, test loss: 9.737440
# Current epoch number: 9899
# Epoch 9899, train loss: 5.060409, test loss: 9.556054
# Current epoch number: 9999
# Epoch 9999, train loss: 5.181675, test loss: 9.264394

# %%
net.eval()
pred = net(test_data)

# %%
for i in np.arange(0,1000,21):
    
    plt.hist(test_data[i].cpu())
    plt.hist(pred.detach().cpu().numpy()[i])
    plt.show()
